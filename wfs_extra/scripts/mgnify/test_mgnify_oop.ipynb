# %%
from mgnify_oop import AbundanceTable, TaxonomyTable

from pathlib import Path
import pandas as pd

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
mgnify = AbundanceTable.from_csv(
    Path.home() / "coding/emo-bon/momics-demos/data/mgnify_data/ERP003634_taxonomy_abundances_SSU_v5.0.tsv",
    sep="\t",
)
# Out:
# INFO:mgnify_oop:Detected source as 'mgnify' based on data format.
# INFO:mgnify_oop:raw MGNify data -> standardizing.
# INFO:mgnify_oop:raw MGNify data -> standardizing.

# %%
mgnify.df
# Out:
# source material ID                                  ERR2010979  ERR315850  \
# taxonomic_concat
# sk__Archaea                                                  4          0
# sk__Archaea;k__;p__Euryarchaeota;c__Candidatus_...         295          0
# sk__Archaea;k__;p__Euryarchaeota;c__Thermoplasmata         261          0
# sk__Archaea;k__;p__Thaumarchaeota;c__;o__Nitros...           3          0
# sk__Bacteria                                               939        202
# ...                                                        ...        ...
# sk__Eukaryota;k__;p__;c__Polycystinea;o__Spumel...           3          0
# sk__Eukaryota;k__;p__Bacillariophyta                         1          0
# sk__Eukaryota;k__Metazoa;p__Arthropoda;c__Malac...           0          1
# sk__Eukaryota;k__Metazoa;p__Chordata;c__Appendi...           1          0
# sk__Eukaryota;k__Viridiplantae                               2          0
#
# source material ID                                  ERR315851  ERR315852  \
# taxonomic_concat
# sk__Archaea                                                 0          0
# sk__Archaea;k__;p__Euryarchaeota;c__Candidatus_...          0          0
# sk__Archaea;k__;p__Euryarchaeota;c__Thermoplasmata          0          0
# sk__Archaea;k__;p__Thaumarchaeota;c__;o__Nitros...          0          0
# sk__Bacteria                                              962        741
# ...                                                       ...        ...
# sk__Eukaryota;k__;p__;c__Polycystinea;o__Spumel...          0          0
# sk__Eukaryota;k__;p__Bacillariophyta                        0          0
# sk__Eukaryota;k__Metazoa;p__Arthropoda;c__Malac...          0          0
# sk__Eukaryota;k__Metazoa;p__Chordata;c__Appendi...          0          0
# sk__Eukaryota;k__Viridiplantae                              0          0
#
# source material ID                                  ERR315853  ERR315854  \
# taxonomic_concat
# sk__Archaea                                                 0          0
# sk__Archaea;k__;p__Euryarchaeota;c__Candidatus_...          0          0
# sk__Archaea;k__;p__Euryarchaeota;c__Thermoplasmata          0          0
# sk__Archaea;k__;p__Thaumarchaeota;c__;o__Nitros...          0          0
# sk__Bacteria                                              669        327
# ...                                                       ...        ...
# sk__Eukaryota;k__;p__;c__Polycystinea;o__Spumel...          0          0
# sk__Eukaryota;k__;p__Bacillariophyta                        0          0
# sk__Eukaryota;k__Metazoa;p__Arthropoda;c__Malac...          0          0
# sk__Eukaryota;k__Metazoa;p__Chordata;c__Appendi...          0          0
# sk__Eukaryota;k__Viridiplantae                              0          0
#
# source material ID                                  ERR315855
# taxonomic_concat
# sk__Archaea                                                 0
# sk__Archaea;k__;p__Euryarchaeota;c__Candidatus_...          0
# sk__Archaea;k__;p__Euryarchaeota;c__Thermoplasmata          0
# sk__Archaea;k__;p__Thaumarchaeota;c__;o__Nitros...          0
# sk__Bacteria                                              424
# ...                                                       ...
# sk__Eukaryota;k__;p__;c__Polycystinea;o__Spumel...          0
# sk__Eukaryota;k__;p__Bacillariophyta                        0
# sk__Eukaryota;k__Metazoa;p__Arthropoda;c__Malac...          0
# sk__Eukaryota;k__Metazoa;p__Chordata;c__Appendi...          0
# sk__Eukaryota;k__Viridiplantae                              0
#
# [497 rows x 7 columns]

# %%
len(mgnify.df), mgnify.df.columns
# Out:
# (497,
#  Index(['ERR2010979', 'ERR315850', 'ERR315851', 'ERR315852', 'ERR315853',
#         'ERR315854', 'ERR315855'],
#        dtype='object', name='source material ID'))

# %%
df = pd.read_csv(
    Path.home() / "coding/emo-bon/momics-demos/data/mgnify_data/ERP003634_taxonomy_abundances_SSU_v5.0.tsv",
    sep="\t",
)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=497, step=1)

# %%
df.columns
# Out:
# Index(['#SampleID', 'ERR2010979', 'ERR315850', 'ERR315851', 'ERR315852',
#        'ERR315853', 'ERR315854', 'ERR315855'],
#       dtype='object')

# %%
df['#SampleID']
# Out:
# 0                                            sk__Archaea
# 1      sk__Archaea;k__;p__Euryarchaeota;c__Candidatus...
# 2      sk__Archaea;k__;p__Euryarchaeota;c__Thermoplas...
# 3      sk__Archaea;k__;p__Thaumarchaeota;c__;o__Nitro...
# 4                                           sk__Bacteria
#                              ...
# 492    sk__Eukaryota;k__;p__;c__Polycystinea;o__Spume...
# 493                 sk__Eukaryota;k__;p__Bacillariophyta
# 494    sk__Eukaryota;k__Metazoa;p__Arthropoda;c__Mala...
# 495    sk__Eukaryota;k__Metazoa;p__Chordata;c__Append...
# 496                       sk__Eukaryota;k__Viridiplantae
# Name: #SampleID, Length: 497, dtype: object

# %%
def is_mgnify_raw(df: pd.DataFrame) -> bool:
    required_cols = {"#SampleID"}
    missing = required_cols - set(df.columns)
    starts_with_sk = bool(df['#SampleID'].str.startswith("sk__").all())
    unique_sample_ids = df['#SampleID'].is_unique
    return len(missing) == 0 and isinstance(df.index, pd.RangeIndex) and unique_sample_ids and starts_with_sk

# %%
is_mgnify_raw(df)
# Out:
# True

# %%
df['#SampleID'].is_unique
# Out:
# True

# %%
bool(df['#SampleID'].str.startswith("sk__").all())
# Out:
# True

# %% [markdown]
# ## Loading emobon data

# %%
import os

# %%
import warnings
import holoviews as hv
from skbio.stats.ordination import pcoa

warnings.filterwarnings('ignore')

import pandas as pd
import panel as pn

# from mgo.udal import UDAL

# All low level functions are imported from the momics package
import momics.plotting as pl
from momics.panel_utils import tax_finder_selector

from momics.diversity import (
    beta_diversity_parametrized,
    find_taxa_in_table,
)
from momics.utils import load_and_clean
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='384254d0-070c-4224-9749-1b869cfd8775'>
#   <div id="b8f54d6b-e532-42ac-b26d-c9fcd0ab3bd6" data-root-id="384254d0-070c-4224-9749-1b869cfd8775" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"50395a8a-62d7-4c39-a3cc-b656351aa7dc":{"version":"3.7.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"384254d0-070c-4224-9749-1b869cfd8775"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"6f6f3b53-b27f-4ed1-9673-d0e234c87129","attributes":{"plot_id":"384254d0-070c-4224-9749-1b869cfd8775","comm_id":"1fed5117194b4fe294f2cbe34d244e02","client_comm_id":"f02d67a367394a59874f851b590c12b4"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1" ...
#   var render_items = [{"docid":"50395a8a-62d7-4c39-a3cc-b656351aa7dc","roots":{"384254d0-070c-4224-9749-1b869cfd8775":"b8f54d6b-e532-42ac-b26d-c9fcd0ab3bd6"},"root_ids":["384254d0-070c-4224-9749-1b869cfd8775"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
root_folder = os.path.abspath(os.path.join('../../../'))
assets_folder = os.path.join(root_folder, 'assets')

def get_valid_samples():
    df_valid = pd.read_csv(
        os.path.join(root_folder, 'data/shipment_b1b2_181.csv')
    )
    return df_valid

valid_samples = get_valid_samples()

# %%
# High level function from the momics.utils module
full_metadata, mgf_parquet_dfs = load_and_clean(valid_samples=valid_samples)

# select categorical columns from metadata
categorical_columns = sorted(full_metadata.select_dtypes(include=['object', "boolean"]).columns)

# select numerical columns from metadata
numerical_columns = sorted(full_metadata.select_dtypes(include=['int64', 'float64']).columns)

# %%
ssu= mgf_parquet_dfs['ssu']

# %%
ssu.head()
# Out:
#                                 abundance superkingdom kingdom  \
# source material ID ncbi_tax_id
# EMOBON_BPNS_So_5   2157               7.0      Archaea    None
#                    1801616            1.0      Archaea
#                    28890              1.0      Archaea
#                    183968             1.0      Archaea
#                    192989             3.0      Archaea
#
#                                                    phylum        class order  \
# source material ID ncbi_tax_id
# EMOBON_BPNS_So_5   2157                              None         None  None
#                    1801616      Candidatus_Woesearchaeota         None  None
#                    28890                    Euryarchaeota         None  None
#                    183968                   Euryarchaeota  Thermococci  None
#                    192989                   Nanoarchaeota         None  None
#
#                                family genus species
# source material ID ncbi_tax_id
# EMOBON_BPNS_So_5   2157          None  None    None
#                    1801616       None  None    None
#                    28890         None  None    None
#                    183968        None  None    None
#                    192989        None  None    None

# %%
isinstance(ssu.index, pd.MultiIndex)
# Out:
# True

# %%
s = TaxonomyTable(ssu)
s.source
# Out:
# INFO:mgnify_oop:Detected source as 'emobon_processed' based on data format.
# 'emobon_processed'

# %%
reset = s.df.reset_index()
reset.columns
# Out:
# Index(['source material ID', 'ncbi_tax_id', 'abundance', 'superkingdom',
#        'kingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species'],
#       dtype='object')

# %%
abundance_table = s.to_abundance_table()
# Out:
# ERROR:mgnify_oop:Error checking MGNify raw format: '#SampleID'

# %%
abundance_table.df.head()
# Out:
# source material ID                                              EMOBON_AAOT_Wa_1  \
# ncbi_tax_id taxonomic_concat
# 2           2;sk__Bacteria;k__;p__;c__;o__;f__;g__;s__;                     1256
# 6           6;sk__Bacteria;k__;p__Proteobacteria;c__Alphapr...                 0
# 10          10;sk__Bacteria;k__;p__Proteobacteria;c__Gammap...                 0
# 16          16;sk__Bacteria;k__;p__Proteobacteria;c__Betapr...                 0
# 18          18;sk__Bacteria;k__;p__Proteobacteria;c__Deltap...                 0
#
# source material ID                                              EMOBON_AAOT_Wa_2  \
# ncbi_tax_id taxonomic_concat
# 2           2;sk__Bacteria;k__;p__;c__;o__;f__;g__;s__;                     1783
# 6           6;sk__Bacteria;k__;p__Proteobacteria;c__Alphapr...                 0
# 10          10;sk__Bacteria;k__;p__Proteobacteria;c__Gammap...                 0
# 16          16;sk__Bacteria;k__;p__Proteobacteria;c__Betapr...                 0
# 18          18;sk__Bacteria;k__;p__Proteobacteria;c__Deltap...                 0
#
# source material ID                                              EMOBON_AAOT_Wa_22  \
# ncbi_tax_id taxonomic_concat
# 2           2;sk__Bacteria;k__;p__;c__;o__;f__;g__;s__;                      1920
# 6           6;sk__Bacteria;k__;p__Proteobacteria;c__Alphapr...                  1
# 10          10;sk__Bacteria;k__;p__Proteobacteria;c__Gammap...                  0
# 16          16;sk__Bacteria;k__;p__Proteobacteria;c__Betapr...                  0
# 18          18;sk__Bacteria;k__;p__Proteobacteria;c__Deltap...                  0
#
# source material ID                                              EMOBON_AAOT_Wa_26  \
# ncbi_tax_id taxonomic_concat
# 2           2;sk__Bacteria;k__;p__;c__;o__;f__;g__;s__;                       895
# 6           6;sk__Bacteria;k__;p__Proteobacteria;c__Alphapr...                  0
# 10          10;sk__Bacteria;k__;p__Proteobacteria;c__Gammap...                  0
# 16          16;sk__Bacteria;k__;p__Proteobacteria;c__Betapr...                  0
# 18          18;sk__Bacteria;k__;p__Proteobacteria;c__Deltap...                  0
#
# source material ID                                              EMOBON_AAOT_Wa_27  \
# ncbi_tax_id taxonomic_concat
# 2           2;sk__Bacteria;k__;p__;c__;o__;f__;g__;s__;                       536
# 6           6;sk__Bacteria;k__;p__Proteobacteria;c__Alphapr...                  0
# 10          10;sk__Bacteria;k__;p__Proteobacteria;c__Gammap...                  0
# 16          16;sk__Bacteria;k__;p__Proteobacteria;c__Betapr...                  0
# 18          18;sk__Bacteria;k__;p__Proteobacteria;c__Deltap...                  0
#
# source material ID                                              EMOBON_AAOT_Wa_41  \
# ncbi_tax_id taxonomic_concat
# 2           2;sk__Bacteria;k__;p__;c__;o__;f__;g__;s__;                       848
# 6           6;sk__Bacteria;k__;p__Proteobacteria;c__Alphapr...                  0
# 10          10;sk__Bacteria;k__;p__Proteobacteria;c__Gammap...                  0
# 16          16;sk__Bacteria;k__;p__Proteobacteria;c__Betapr...                  0
# 18          18;sk__Bacteria;k__;p__Proteobacteria;c__Deltap...                  0
#
# source material ID                                              EMOBON_AAOT_Wa_42  \
# ncbi_tax_id taxonomic_concat
# 2           2;sk__Bacteria;k__;p__;c__;o__;f__;g__;s__;                       461
# 6           6;sk__Bacteria;k__;p__Proteobacteria;c__Alphapr...                  0
# 10          10;sk__Bacteria;k__;p__Proteobacteria;c__Gammap...                  0
# 16          16;sk__Bacteria;k__;p__Proteobacteria;c__Betapr...                  0
# 18          18;sk__Bacteria;k__;p__Proteobacteria;c__Deltap...                  0
#
# source material ID                                              EMOBON_AAOT_Wa_46  \
# ncbi_tax_id taxonomic_concat
# 2           2;sk__Bacteria;k__;p__;c__;o__;f__;g__;s__;                       534
# 6           6;sk__Bacteria;k__;p__Proteobacteria;c__Alphapr...                  0
# 10          10;sk__Bacteria;k__;p__Proteobacteria;c__Gammap...                  0
# 16          16;sk__Bacteria;k__;p__Proteobacteria;c__Betapr...                  0
# 18          18;sk__Bacteria;k__;p__Proteobacteria;c__Deltap...                  0
#
# source material ID                                              EMOBON_AAOT_Wa_47  \
# ncbi_tax_id taxonomic_concat
# 2           2;sk__Bacteria;k__;p__;c__;o__;f__;g__;s__;                       304
# 6           6;sk__Bacteria;k__;p__Proteobacteria;c__Alphapr...                  0
# 10          10;sk__Bacteria;k__;p__Proteobacteria;c__Gammap...                  0
# 16          16;sk__Bacteria;k__;p__Proteobacteria;c__Betapr...                  0
# 18          18;sk__Bacteria;k__;p__Proteobacteria;c__Deltap...                  0
#
# source material ID                                              EMOBON_AAOT_Wa_6  \
# ncbi_tax_id taxonomic_concat
# 2           2;sk__Bacteria;k__;p__;c__;o__;f__;g__;s__;                     1172
# 6           6;sk__Bacteria;k__;p__Proteobacteria;c__Alphapr...                 0
# 10          10;sk__Bacteria;k__;p__Proteobacteria;c__Gammap...                 0
# 16          16;sk__Bacteria;k__;p__Proteobacteria;c__Betapr...                 0
# 18          18;sk__Bacteria;k__;p__Proteobacteria;c__Deltap...                 0
#
# source material ID                                              ...  \
# ncbi_tax_id taxonomic_concat                                    ...
# 2           2;sk__Bacteria;k__;p__;c__;o__;f__;g__;s__;         ...
# 6           6;sk__Bacteria;k__;p__Proteobacteria;c__Alphapr...  ...
# 10          10;sk__Bacteria;k__;p__Proteobacteria;c__Gammap...  ...
# 16          16;sk__Bacteria;k__;p__Proteobacteria;c__Betapr...  ...
# 18          18;sk__Bacteria;k__;p__Proteobacteria;c__Deltap...  ...
#
# source material ID                                              EMOBON_VB_Wa_4  \
# ncbi_tax_id taxonomic_concat
# 2           2;sk__Bacteria;k__;p__;c__;o__;f__;g__;s__;                    765
# 6           6;sk__Bacteria;k__;p__Proteobacteria;c__Alphapr...               0
# 10          10;sk__Bacteria;k__;p__Proteobacteria;c__Gammap...               0
# 16          16;sk__Bacteria;k__;p__Proteobacteria;c__Betapr...               0
# 18          18;sk__Bacteria;k__;p__Proteobacteria;c__Deltap...               0
#
# source material ID                                              EMOBON_VB_Wa_41  \
# ncbi_tax_id taxonomic_concat
# 2           2;sk__Bacteria;k__;p__;c__;o__;f__;g__;s__;                     769
# 6           6;sk__Bacteria;k__;p__Proteobacteria;c__Alphapr...                0
# 10          10;sk__Bacteria;k__;p__Proteobacteria;c__Gammap...                0
# 16          16;sk__Bacteria;k__;p__Proteobacteria;c__Betapr...                0
# 18          18;sk__Bacteria;k__;p__Proteobacteria;c__Deltap...                0
#
# source material ID                                              EMOBON_VB_Wa_42  \
# ncbi_tax_id taxonomic_concat
# 2           2;sk__Bacteria;k__;p__;c__;o__;f__;g__;s__;                    1106
# 6           6;sk__Bacteria;k__;p__Proteobacteria;c__Alphapr...                0
# 10          10;sk__Bacteria;k__;p__Proteobacteria;c__Gammap...                0
# 16          16;sk__Bacteria;k__;p__Proteobacteria;c__Betapr...                0
# 18          18;sk__Bacteria;k__;p__Proteobacteria;c__Deltap...                0
#
# source material ID                                              EMOBON_VB_Wa_43  \
# ncbi_tax_id taxonomic_concat
# 2           2;sk__Bacteria;k__;p__;c__;o__;f__;g__;s__;                    1449
# 6           6;sk__Bacteria;k__;p__Proteobacteria;c__Alphapr...                0
# 10          10;sk__Bacteria;k__;p__Proteobacteria;c__Gammap...                0
# 16          16;sk__Bacteria;k__;p__Proteobacteria;c__Betapr...                0
# 18          18;sk__Bacteria;k__;p__Proteobacteria;c__Deltap...                0
#
# source material ID                                              EMOBON_VB_Wa_44  \
# ncbi_tax_id taxonomic_concat
# 2           2;sk__Bacteria;k__;p__;c__;o__;f__;g__;s__;                     996
# 6           6;sk__Bacteria;k__;p__Proteobacteria;c__Alphapr...                0
# 10          10;sk__Bacteria;k__;p__Proteobacteria;c__Gammap...                0
# 16          16;sk__Bacteria;k__;p__Proteobacteria;c__Betapr...                0
# 18          18;sk__Bacteria;k__;p__Proteobacteria;c__Deltap...                0
#
# source material ID                                              EMOBON_VB_Wa_5  \
# ncbi_tax_id taxonomic_concat
# 2           2;sk__Bacteria;k__;p__;c__;o__;f__;g__;s__;                    978
# 6           6;sk__Bacteria;k__;p__Proteobacteria;c__Alphapr...               0
# 10          10;sk__Bacteria;k__;p__Proteobacteria;c__Gammap...               0
# 16          16;sk__Bacteria;k__;p__Proteobacteria;c__Betapr...               0
# 18          18;sk__Bacteria;k__;p__Proteobacteria;c__Deltap...               0
#
# source material ID                                              EMOBON_VB_Wa_93  \
# ncbi_tax_id taxonomic_concat
# 2           2;sk__Bacteria;k__;p__;c__;o__;f__;g__;s__;                     456
# 6           6;sk__Bacteria;k__;p__Proteobacteria;c__Alphapr...                0
# 10          10;sk__Bacteria;k__;p__Proteobacteria;c__Gammap...                0
# 16          16;sk__Bacteria;k__;p__Proteobacteria;c__Betapr...                0
# 18          18;sk__Bacteria;k__;p__Proteobacteria;c__Deltap...                0
#
# source material ID                                              EMOBON_VB_Wa_94  \
# ncbi_tax_id taxonomic_concat
# 2           2;sk__Bacteria;k__;p__;c__;o__;f__;g__;s__;                     552
# 6           6;sk__Bacteria;k__;p__Proteobacteria;c__Alphapr...                0
# 10          10;sk__Bacteria;k__;p__Proteobacteria;c__Gammap...                0
# 16          16;sk__Bacteria;k__;p__Proteobacteria;c__Betapr...                0
# 18          18;sk__Bacteria;k__;p__Proteobacteria;c__Deltap...                0
#
# source material ID                                              EMOBON_VB_Wa_96  \
# ncbi_tax_id taxonomic_concat
# 2           2;sk__Bacteria;k__;p__;c__;o__;f__;g__;s__;                    1908
# 6           6;sk__Bacteria;k__;p__Proteobacteria;c__Alphapr...                0
# 10          10;sk__Bacteria;k__;p__Proteobacteria;c__Gammap...                0
# 16          16;sk__Bacteria;k__;p__Proteobacteria;c__Betapr...                0
# 18          18;sk__Bacteria;k__;p__Proteobacteria;c__Deltap...                0
#
# source material ID                                              EMOBON_VB_Wa_97
# ncbi_tax_id taxonomic_concat
# 2           2;sk__Bacteria;k__;p__;c__;o__;f__;g__;s__;                    1120
# 6           6;sk__Bacteria;k__;p__Proteobacteria;c__Alphapr...                0
# 10          10;sk__Bacteria;k__;p__Proteobacteria;c__Gammap...                0
# 16          16;sk__Bacteria;k__;p__Proteobacteria;c__Betapr...                0
# 18          18;sk__Bacteria;k__;p__Proteobacteria;c__Deltap...                0
#
# [5 rows x 181 columns]

# %%
abundance_table.has_tax_ids
# Out:
# True

# %%
mgnify.df.columns
# Out:
# Index(['ERR2010979', 'ERR315850', 'ERR315851', 'ERR315852', 'ERR315853',
#        'ERR315854', 'ERR315855'],
#       dtype='object')

# %%
# name the column index name
mgnify.df.columns.name = "source material ID"

# %%
mgnify.df.columns
# Out:
# Index(['ERR2010979', 'ERR315850', 'ERR315851', 'ERR315852', 'ERR315853',
#        'ERR315854', 'ERR315855'],
#       dtype='object', name='source material ID')

# %%
len(mgnify.df.columns)
# Out:
# 7

# %%
abundance_table.df.columns[:5]
# Out:
# Index(['EMOBON_AAOT_Wa_1', 'EMOBON_AAOT_Wa_2', 'EMOBON_AAOT_Wa_22',
#        'EMOBON_AAOT_Wa_26', 'EMOBON_AAOT_Wa_27'],
#       dtype='object', name='source material ID')
