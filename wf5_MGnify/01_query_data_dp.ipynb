# %% [markdown]
# # Download Mgnify analysis results
#
# ![MGnify](../assets/figs/mgnify_banner.png)
#
# 1. search studies
# 2. get analyses in a dataframe and save them as `.parquet`
# 3. compare to local data

# %%
# Connection to MGnify API

# this repo is not maintained, or less than jsonapi-requests
# consider a dep change
from jsonapi_client import Session as APISession
from jsonapi_client import Modifier
import requests

# Dataframes and display
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# Data transformation
from functools import reduce

# Plots
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
# %matplotlib inline 

# Create signature of MAGs for comparison against database
import sourmash
import glob
import time
from pathlib import PurePath as pp
from Bio import SeqIO

# Warning verbosity
import warnings 
warnings.filterwarnings(action="ignore")

# %% [markdown]
# ## Query analyses
#
# Use analyses endpoint.
# A complete list of endpoints can be found at https://www.ebi.ac.uk/metagenomics/api/v1/.

# %%
# GET /metagenomics/api/v1/
r = requests.get(f"https://www.ebi.ac.uk/metagenomics/api/v1/")
r.json()['data']
# Out:
# {'biomes': 'https://www.ebi.ac.uk/metagenomics/api/v1/biomes',
#  'studies': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies',
#  'super-studies': 'https://www.ebi.ac.uk/metagenomics/api/v1/super-studies',
#  'samples': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples',
#  'runs': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs',
#  'assemblies': 'https://www.ebi.ac.uk/metagenomics/api/v1/assemblies',
#  'analyses': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses',
#  'experiment-types': 'https://www.ebi.ac.uk/metagenomics/api/v1/experiment-types',
#  'pipelines': 'https://www.ebi.ac.uk/metagenomics/api/v1/pipelines',
#  'pipeline-tools': 'https://www.ebi.ac.uk/metagenomics/api/v1/pipeline-tools',
#  'publications': 'https://www.ebi.ac.uk/metagenomics/api/v1/publications',
#  'genomes': 'https://www.ebi.ac.uk/metagenomics/api/v1/genomes',
#  'genome-search': 'https://www.ebi.ac.uk/metagenomics/api/v1/genome-search',
#  'genomes-search/gather': 'https://www.ebi.ac.uk/metagenomics/api/v1/genomes-search/gather',
#  'genome-catalogues': 'https://www.ebi.ac.uk/metagenomics/api/v1/genome-catalogues',
#  'genomeset': 'https://www.ebi.ac.uk/metagenomics/api/v1/genomeset',
#  'cogs': 'https://www.ebi.ac.uk/metagenomics/api/v1/cogs',
#  'kegg-modules': 'https://www.ebi.ac.uk/metagenomics/api/v1/kegg-modules',
#  'kegg-classes': 'https://www.ebi.ac.uk/metagenomics/api/v1/kegg-classes',
#  'antismash-geneclusters': 'https://www.ebi.ac.uk/metagenomics/api/v1/antismash-geneclusters',
#  'annotations/go-terms': 'https://www.ebi.ac.uk/metagenomics/api/v1/annotations/go-terms',
#  'annotations/interpro-identifiers': 'https://www.ebi.ac.uk/metagenomics/api/v1/annotations/interpro-identifiers',
#  'annotations/kegg-modules': 'https://www.ebi.ac.uk/metagenomics/api/v1/annotations/kegg-modules',
#  'annotations/pfam-entries': 'https://www.ebi.ac.uk/metagenomics/api/v1/annotations/pfam-entries',
#  'annotations/kegg-orthologs': 'https://www.ebi.ac.uk/metagenomics/api/v1/annotations/kegg-orthologs',
#  'annotations/genome-properties': 'https://www.ebi.ac.uk/metagenomics/api/v1/annotations/genome-properties',
#  'annotations/antismash-gene-clusters': 'https://www.ebi.ac.uk/metagenomics/api/v1/annotations/antismash-gene-clusters',
#  'annotations/organisms': 'https://www.ebi.ac.uk/metagenomics/api/v1/annotations/organisms',
#  'mydata': 'https://www.ebi.ac.uk/metagenomics/api/v1/mydata'}

# %%
endpoint_name = 'analyses'
r = requests.get(f"https://www.ebi.ac.uk/metagenomics/api/v1/{endpoint_name}")
r.json()['data'][0]
# Out:
# {'type': 'analysis-jobs',
#  'id': 'MGYA00383253',
#  'attributes': {'pipeline-version': '5.0',
#   'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#     'value': '55799'},
#    {'key': 'Nucleotide sequences after format-specific filtering',
#     'value': '55789'},
#    {'key': 'Nucleotide sequences after length filtering', 'value': '55789'},
#    {'key': 'Nucleotide sequences after undetermined bases filtering',
#     'value': '55789'},
#    {'key': 'Predicted SSU sequences', 'value': '0'},
#    {'key': 'Predicted LSU sequences', 'value': '461'}],
#   'accession': 'MGYA00383253',
#   'experiment-type': 'amplicon',
#   'analysis-status': 'completed',
#   'is-private': False,
#   'last-update': '2024-01-29T15:29:19.757516',
#   'mgx-accession': None,
#   'complete-time': '2020-06-11T10:51:27',
#   'instrument-platform': 'ILLUMINA',
#   'instrument-model': 'Illumina MiSeq'},
#  'relationships': {'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253/taxonomy/lsu'}},
#   'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253/taxonomy/unite'}},
#   'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253/interpro-identifiers'}},
#   'study': {'data': {'type': 'studies', 'id': 'MGYS00002115'},
#    'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002115'}},
#   'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253/taxonomy/itsonedb'}},
#   'run': {'data': {'type': 'runs', 'id': 'ERR2237853'},
#    'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR2237853'}},
#   'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253/taxonomy/ssu'}},
#   'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253/downloads'}},
#   'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253/genome-properties'}},
#   'sample': {'data': {'type': 'samples', 'id': 'ERS2075820'},
#    'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS2075820'}},
#   'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253/antismash-gene-clusters'}},
#   'assembly': {'data': None},
#   'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253/taxonomy'}},
#   'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253/go-slim'}},
#   'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253/go-terms'}}},
#  'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253'}}

# %%
# by accession
endpoint_name = 'studies'
accession = 'MGYS00002392'
r = requests.get(f"https://www.ebi.ac.uk/metagenomics/api/v1/{endpoint_name}/{accession}")
r.json()['data']
# Out:
# {'type': 'studies',
#  'id': 'MGYS00002392',
#  'attributes': {'samples-count': 1073,
#   'bioproject': 'PRJEB6610',
#   'accession': 'MGYS00002392',
#   'is-private': False,
#   'last-update': '2024-04-15T20:15:45',
#   'secondary-accession': 'ERP006157',
#   'centre-name': 'GSC',
#   'public-release-date': None,
#   'study-abstract': 'Analysis of 18S DNA in Tara Oceans Protists size fractions through amplicon sequencing: Seawater was filtered from different depths to retain small and large cell sizes. The DNA was extracted and amplified by PCR.',
#   'study-name': 'Amplicon sequencing of Tara Oceans DNA samples corresponding to size fractions for protists.',
#   'data-origination': 'SUBMITTED'},
#  'relationships': {'analyses': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392/analyses'}},
#   'publications': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392/publications'}},
#   'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392/downloads'}},
#   'samples': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392/samples'}},
#   'studies': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392/studies'},
#    'data': [{'type': 'studies',
#      'id': 'MGYS00000410',
#      'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00000410'}},
#     {'type': 'studies',
#      'id': 'MGYS00000492',
#      'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00000492'}},
#     {'type': 'studies',
#      'id': 'MGYS00001306',
#      'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00001306'}},
#     {'type': 'studies',
#      'id': 'MGYS00001482',
#      'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00001482'}},
#     {'type': 'studies',
#      'id': 'MGYS00001789',
#      'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00001789'}},
#     {'type': 'studies',
#      'id': 'MGYS00002008',
#      'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002008'}},
#     {'type': 'studies',
#      'id': 'MGYS00002368',
#      'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002368'}},
#     {'type': 'studies',
#      'id': 'MGYS00006058',
#      'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00006058'}},
#     {'type': 'studies',
#      'id': 'MGYS00006074',
#      'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00006074'}},
#     {'type': 'studies',
#      'id': 'MGYS00006075',
#      'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00006075'}},
#     {'type': 'studies',
#      'id': 'MGYS00006491',
#      'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00006491'}},
#     {'type': 'studies',
#      'id': 'MGYS00006605',
#      'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00006605'}},
#     {'type': 'studies',
#      'id': 'MGYS00006606',
#      'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00006606'}}]},
#   'biomes': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392/biomes'},
#    'data': [{'type': 'biomes',
#      'id': 'root:Environmental:Aquatic:Marine',
#      'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/biomes/root:Environmental:Aquatic:Marine'}},
#     {'type': 'biomes',
#      'id': 'root:Environmental:Aquatic:Marine:Oceanic',
#      'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/biomes/root:Environmental:Aquatic:Marine:Oceanic'}}]},
#   'geocoordinates': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392/geocoordinates'}}},
#  'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392'}}

# %%
r = requests.get("https://www.ebi.ac.uk/metagenomics/studies/MGYS00006680/pipelines/5.0/file")
r.content.decode('utf-8')
# Out:
# '<!doctype html><html lang="en"><head><meta charset="utf-8"/><meta name="viewport" content="width=device-width,initial-scale=1"><link rel="stylesheet" href="https://assets.emblstatic.net/vf/v2.5.7/css/styles.css"/><link rel="stylesheet" href="https://assets.emblstatic.net/vf/v2.5.7/assets/ebi-header-footer/ebi-header-footer.css"/><link rel="stylesheet" href="//ebi.emblstatic.net/web_guidelines/EBI-Icon-fonts/v1.3/fonts.css" media="all"/><link rel="stylesheet" href="https://stable.visual-framework.dev/assets/vf-banner-elixir/vf-banner-elixir.css"/><title>MGnify - EBI</title><script>// Single Page Apps for GitHub Pages\n      // MIT License\n      // https://github.com/rafgraph/spa-github-pages\n      // This script checks to see if a redirect is present in the query string,\n      // converts it back into the correct url and adds it to the\n      // browser\'s history using window.history.replaceState(...),\n      // which won\'t cause the browser to attempt to load the new url.\n      // When the single page app is loaded further down in this file,\n      // the correct url will be waiting in the browser\'s history for\n      // the single page app to route accordingly.\n      (function (l) {\n        if (l.search[1] === \'/\') {\n          var decoded = l.search\n            .slice(1)\n            .split(\'&\')\n            .map(function (s) {\n              return s.replace(/~and~/g, \'&\');\n            })\n            .join(\'?\');\n          window.history.replaceState(\n            null,\n            null,\n            l.pathname.slice(0, -1) + decoded + l.hash\n          );\n        }\n      })(window.location);</script><script defer="defer" src="js/main.c481e096.js"></script><link href="css/main.b259ed93.css" rel="stylesheet"></head><body class="vf-body vf-stack ebi-black-bar-loaded embl-content-hub-loaded"><div id="root"></div></body></html>'

# %%
# display the html
import IPython
IPython.display.HTML(r.content.decode('utf-8'))
# Out:
# <!doctype html><html lang="en"><head><meta charset="utf-8"/><meta name="viewport" content="width=device-width,initial-scale=1"><link rel="stylesheet" href="https://assets.emblstatic.net/vf/v2.5.7/css/styles.css"/><link rel="stylesheet" href="https://assets.emblstatic.net/vf/v2.5.7/assets/ebi-header-footer/ebi-header-footer.css"/><link rel="stylesheet" href="//ebi.emblstatic.net/web_guidelines/EBI-Icon-fonts/v1.3/fonts.css" media="all"/><link rel="stylesheet" href="https://stable.visual-framework.dev/assets/vf-banner-elixir/vf-banner-elixir.css"/><title>MGnify - EBI</title><script>// Single Page Apps for GitHub Pages
#       // MIT License
#       // https://github.com/rafgraph/spa-github-pages
#       // This script checks to see if a redirect is present in the query string,
#       // converts it back into the correct url and adds it to the
#       // browser's history using window.history.replaceState(...),
#       // which won't cause the browser to attempt to load the new url.
#       // When the single page app is loaded further down in this file,
#       // the correct url will be waiting in the browser's history for
#       // the single page app to route accordingly.
#       (function (l) {
#         if (l.search[1] === '/') {
#           var decoded = l.search
#             .slice(1)
#             .split('&')
#             .map(function (s) {
#               return s.replace(/~and~/g, '&');
#             })
#             .join('?');
#           window.history.replaceState(
#             null,
#             null,
#             l.pathname.slice(0, -1) + decoded + l.hash
#           );
#         }
#       })(window.location);</script><script defer="defer" src="js/main.c481e096.js"></script><link href="css/main.b259ed93.css" rel="stylesheet"></head><body class="vf-body vf-stack ebi-black-bar-loaded embl-content-hub-loaded"><div id="root"></div></body></html>

# %%
r = requests.get(f"https://www.ebi.ac.uk/metagenomics/api/v1/{endpoint_name}/{accession}/analyses")
r.json()['data']
# Out:
# [{'type': 'analysis-jobs',
#   'id': 'MGYA00722743',
#   'attributes': {'analysis-status': 'completed',
#    'pipeline-version': '5.0',
#    'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#      'value': '2050402'},
#     {'key': 'Nucleotide sequences after format-specific filtering',
#      'value': '1357633'},
#     {'key': 'Nucleotide sequences after length filtering', 'value': '1357633'},
#     {'key': 'Nucleotide sequences after undetermined bases filtering',
#      'value': '1357633'},
#     {'key': 'Predicted LSU sequences', 'value': '1'},
#     {'key': 'Predicted SSU sequences', 'value': '1355389'}],
#    'experiment-type': 'amplicon',
#    'accession': 'MGYA00722743',
#    'is-private': False,
#    'last-update': '2024-02-28T22:10:08.862460',
#    'mgx-accession': 'MGX0000886',
#    'complete-time': '2024-02-28T22:10:07',
#    'instrument-platform': 'ILLUMINA',
#    'instrument-model': 'Illumina Genome Analyzer IIx'},
#   'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743/go-terms'}},
#    'run': {'data': {'type': 'runs', 'id': 'ERR566174'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR566174'}},
#    'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743/downloads'}},
#    'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743/go-slim'}},
#    'assembly': {'data': None},
#    'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743/interpro-identifiers'}},
#    'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743/taxonomy/unite'}},
#    'study': {'data': {'type': 'studies', 'id': 'MGYS00002392'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392'}},
#    'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743/taxonomy/ssu'}},
#    'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743/taxonomy/lsu'}},
#    'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743/taxonomy/itsonedb'}},
#    'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743/antismash-gene-clusters'}},
#    'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743/taxonomy'}},
#    'sample': {'data': {'type': 'samples', 'id': 'ERS506046'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS506046'}},
#    'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743/genome-properties'}}},
#   'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743'}},
#  {'type': 'analysis-jobs',
#   'id': 'MGYA00722744',
#   'attributes': {'analysis-status': 'completed',
#    'pipeline-version': '5.0',
#    'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#      'value': '2899522'},
#     {'key': 'Nucleotide sequences after format-specific filtering',
#      'value': '1261859'},
#     {'key': 'Nucleotide sequences after length filtering', 'value': '1261859'},
#     {'key': 'Nucleotide sequences after undetermined bases filtering',
#      'value': '1261859'},
#     {'key': 'Predicted LSU sequences', 'value': '0'},
#     {'key': 'Predicted SSU sequences', 'value': '1261348'}],
#    'experiment-type': 'amplicon',
#    'accession': 'MGYA00722744',
#    'is-private': False,
#    'last-update': '2024-02-28T22:10:26.857803',
#    'mgx-accession': 'MGX0000887',
#    'complete-time': '2024-02-28T22:10:26',
#    'instrument-platform': 'ILLUMINA',
#    'instrument-model': 'Illumina Genome Analyzer IIx'},
#   'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744/go-terms'}},
#    'run': {'data': {'type': 'runs', 'id': 'ERR562730'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR562730'}},
#    'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744/downloads'}},
#    'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744/go-slim'}},
#    'assembly': {'data': None},
#    'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744/interpro-identifiers'}},
#    'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744/taxonomy/unite'}},
#    'study': {'data': {'type': 'studies', 'id': 'MGYS00002392'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392'}},
#    'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744/taxonomy/ssu'}},
#    'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744/taxonomy/lsu'}},
#    'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744/taxonomy/itsonedb'}},
#    'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744/antismash-gene-clusters'}},
#    'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744/taxonomy'}},
#    'sample': {'data': {'type': 'samples', 'id': 'ERS492004'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS492004'}},
#    'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744/genome-properties'}}},
#   'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744'}},
#  {'type': 'analysis-jobs',
#   'id': 'MGYA00722745',
#   'attributes': {'analysis-status': 'completed',
#    'pipeline-version': '5.0',
#    'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#      'value': '2340317'},
#     {'key': 'Nucleotide sequences after format-specific filtering',
#      'value': '1252642'},
#     {'key': 'Nucleotide sequences after length filtering', 'value': '1252642'},
#     {'key': 'Nucleotide sequences after undetermined bases filtering',
#      'value': '1252642'},
#     {'key': 'Predicted LSU sequences', 'value': '0'},
#     {'key': 'Predicted SSU sequences', 'value': '1242884'}],
#    'experiment-type': 'amplicon',
#    'accession': 'MGYA00722745',
#    'is-private': False,
#    'last-update': '2024-02-28T22:10:42.722510',
#    'mgx-accession': 'MGX0000888',
#    'complete-time': '2024-02-28T22:10:41',
#    'instrument-platform': 'ILLUMINA',
#    'instrument-model': 'Illumina Genome Analyzer IIx'},
#   'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722745/go-terms'}},
#    'run': {'data': {'type': 'runs', 'id': 'ERR562729'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR562729'}},
#    'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722745/downloads'}},
#    'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722745/go-slim'}},
#    'assembly': {'data': None},
#    'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722745/interpro-identifiers'}},
#    'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722745/taxonomy/unite'}},
#    'study': {'data': {'type': 'studies', 'id': 'MGYS00002392'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392'}},
#    'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722745/taxonomy/ssu'}},
#    'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722745/taxonomy/lsu'}},
#    'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722745/taxonomy/itsonedb'}},
#    'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722745/antismash-gene-clusters'}},
#    'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722745/taxonomy'}},
#    'sample': {'data': {'type': 'samples', 'id': 'ERS488753'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS488753'}},
#    'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722745/genome-properties'}}},
#   'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722745'}},
#  {'type': 'analysis-jobs',
#   'id': 'MGYA00722746',
#   'attributes': {'analysis-status': 'completed',
#    'pipeline-version': '5.0',
#    'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#      'value': '3413729'},
#     {'key': 'Nucleotide sequences after format-specific filtering',
#      'value': '2485084'},
#     {'key': 'Nucleotide sequences after length filtering', 'value': '2485084'},
#     {'key': 'Nucleotide sequences after undetermined bases filtering',
#      'value': '2485084'},
#     {'key': 'Predicted LSU sequences', 'value': '1'},
#     {'key': 'Predicted SSU sequences', 'value': '2449836'}],
#    'experiment-type': 'amplicon',
#    'accession': 'MGYA00722746',
#    'is-private': False,
#    'last-update': '2024-02-28T22:10:59.746018',
#    'mgx-accession': 'MGX0000889',
#    'complete-time': '2024-02-28T22:10:59',
#    'instrument-platform': 'ILLUMINA',
#    'instrument-model': 'Illumina Genome Analyzer IIx'},
#   'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722746/go-terms'}},
#    'run': {'data': {'type': 'runs', 'id': 'ERR562728'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR562728'}},
#    'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722746/downloads'}},
#    'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722746/go-slim'}},
#    'assembly': {'data': None},
#    'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722746/interpro-identifiers'}},
#    'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722746/taxonomy/unite'}},
#    'study': {'data': {'type': 'studies', 'id': 'MGYS00002392'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392'}},
#    'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722746/taxonomy/ssu'}},
#    'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722746/taxonomy/lsu'}},
#    'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722746/taxonomy/itsonedb'}},
#    'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722746/antismash-gene-clusters'}},
#    'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722746/taxonomy'}},
#    'sample': {'data': {'type': 'samples', 'id': 'ERS488633'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS488633'}},
#    'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722746/genome-properties'}}},
#   'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722746'}},
#  {'type': 'analysis-jobs',
#   'id': 'MGYA00722747',
#   'attributes': {'analysis-status': 'completed',
#    'pipeline-version': '5.0',
#    'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#      'value': '2143898'},
#     {'key': 'Nucleotide sequences after format-specific filtering',
#      'value': '1484617'},
#     {'key': 'Nucleotide sequences after length filtering', 'value': '1484617'},
#     {'key': 'Nucleotide sequences after undetermined bases filtering',
#      'value': '1484617'},
#     {'key': 'Predicted LSU sequences', 'value': '0'},
#     {'key': 'Predicted SSU sequences', 'value': '1483910'}],
#    'experiment-type': 'amplicon',
#    'accession': 'MGYA00722747',
#    'is-private': False,
#    'last-update': '2024-02-28T22:11:18.516067',
#    'mgx-accession': 'MGX0000890',
#    'complete-time': '2024-02-28T22:11:17',
#    'instrument-platform': 'ILLUMINA',
#    'instrument-model': 'Illumina Genome Analyzer IIx'},
#   'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722747/go-terms'}},
#    'run': {'data': {'type': 'runs', 'id': 'ERR562727'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR562727'}},
#    'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722747/downloads'}},
#    'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722747/go-slim'}},
#    'assembly': {'data': None},
#    'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722747/interpro-identifiers'}},
#    'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722747/taxonomy/unite'}},
#    'study': {'data': {'type': 'studies', 'id': 'MGYS00002392'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392'}},
#    'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722747/taxonomy/ssu'}},
#    'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722747/taxonomy/lsu'}},
#    'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722747/taxonomy/itsonedb'}},
#    'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722747/antismash-gene-clusters'}},
#    'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722747/taxonomy'}},
#    'sample': {'data': {'type': 'samples', 'id': 'ERS488262'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS488262'}},
#    'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722747/genome-properties'}}},
#   'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722747'}},
#  {'type': 'analysis-jobs',
#   'id': 'MGYA00722748',
#   'attributes': {'analysis-status': 'completed',
#    'pipeline-version': '5.0',
#    'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#      'value': '2950337'},
#     {'key': 'Nucleotide sequences after format-specific filtering',
#      'value': '1926962'},
#     {'key': 'Nucleotide sequences after length filtering', 'value': '1926962'},
#     {'key': 'Nucleotide sequences after undetermined bases filtering',
#      'value': '1926962'},
#     {'key': 'Predicted LSU sequences', 'value': '0'},
#     {'key': 'Predicted SSU sequences', 'value': '1907994'}],
#    'experiment-type': 'amplicon',
#    'accession': 'MGYA00722748',
#    'is-private': False,
#    'last-update': '2024-02-28T22:11:34.465881',
#    'mgx-accession': 'MGX0000891',
#    'complete-time': '2024-02-28T22:11:33',
#    'instrument-platform': 'ILLUMINA',
#    'instrument-model': 'Illumina Genome Analyzer IIx'},
#   'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722748/go-terms'}},
#    'run': {'data': {'type': 'runs', 'id': 'ERR562725'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR562725'}},
#    'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722748/downloads'}},
#    'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722748/go-slim'}},
#    'assembly': {'data': None},
#    'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722748/interpro-identifiers'}},
#    'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722748/taxonomy/unite'}},
#    'study': {'data': {'type': 'studies', 'id': 'MGYS00002392'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392'}},
#    'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722748/taxonomy/ssu'}},
#    'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722748/taxonomy/lsu'}},
#    'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722748/taxonomy/itsonedb'}},
#    'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722748/antismash-gene-clusters'}},
#    'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722748/taxonomy'}},
#    'sample': {'data': {'type': 'samples', 'id': 'ERS492804'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS492804'}},
#    'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722748/genome-properties'}}},
#   'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722748'}},
#  {'type': 'analysis-jobs',
#   'id': 'MGYA00722749',
#   'attributes': {'analysis-status': 'completed',
#    'pipeline-version': '5.0',
#    'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#      'value': '2267834'},
#     {'key': 'Nucleotide sequences after format-specific filtering',
#      'value': '901658'},
#     {'key': 'Nucleotide sequences after length filtering', 'value': '901658'},
#     {'key': 'Nucleotide sequences after undetermined bases filtering',
#      'value': '901658'},
#     {'key': 'Predicted LSU sequences', 'value': '0'},
#     {'key': 'Predicted SSU sequences', 'value': '889259'}],
#    'experiment-type': 'amplicon',
#    'accession': 'MGYA00722749',
#    'is-private': False,
#    'last-update': '2024-02-28T22:11:54.922235',
#    'mgx-accession': 'MGX0000892',
#    'complete-time': '2024-02-28T22:11:54',
#    'instrument-platform': 'ILLUMINA',
#    'instrument-model': 'Illumina Genome Analyzer IIx'},
#   'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722749/go-terms'}},
#    'run': {'data': {'type': 'runs', 'id': 'ERR562716'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR562716'}},
#    'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722749/downloads'}},
#    'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722749/go-slim'}},
#    'assembly': {'data': None},
#    'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722749/interpro-identifiers'}},
#    'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722749/taxonomy/unite'}},
#    'study': {'data': {'type': 'studies', 'id': 'MGYS00002392'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392'}},
#    'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722749/taxonomy/ssu'}},
#    'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722749/taxonomy/lsu'}},
#    'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722749/taxonomy/itsonedb'}},
#    'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722749/antismash-gene-clusters'}},
#    'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722749/taxonomy'}},
#    'sample': {'data': {'type': 'samples', 'id': 'ERS490668'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS490668'}},
#    'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722749/genome-properties'}}},
#   'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722749'}},
#  {'type': 'analysis-jobs',
#   'id': 'MGYA00722750',
#   'attributes': {'analysis-status': 'completed',
#    'pipeline-version': '5.0',
#    'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#      'value': '2947000'},
#     {'key': 'Nucleotide sequences after format-specific filtering',
#      'value': '1969768'},
#     {'key': 'Nucleotide sequences after length filtering', 'value': '1969768'},
#     {'key': 'Nucleotide sequences after undetermined bases filtering',
#      'value': '1969768'},
#     {'key': 'Predicted LSU sequences', 'value': '0'},
#     {'key': 'Predicted SSU sequences', 'value': '1966325'}],
#    'experiment-type': 'amplicon',
#    'accession': 'MGYA00722750',
#    'is-private': False,
#    'last-update': '2024-02-28T22:12:12.437412',
#    'mgx-accession': 'MGX0000893',
#    'complete-time': '2024-02-28T22:12:11',
#    'instrument-platform': 'ILLUMINA',
#    'instrument-model': 'Illumina Genome Analyzer IIx'},
#   'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722750/go-terms'}},
#    'run': {'data': {'type': 'runs', 'id': 'ERR562696'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR562696'}},
#    'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722750/downloads'}},
#    'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722750/go-slim'}},
#    'assembly': {'data': None},
#    'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722750/interpro-identifiers'}},
#    'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722750/taxonomy/unite'}},
#    'study': {'data': {'type': 'studies', 'id': 'MGYS00002392'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392'}},
#    'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722750/taxonomy/ssu'}},
#    'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722750/taxonomy/lsu'}},
#    'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722750/taxonomy/itsonedb'}},
#    'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722750/antismash-gene-clusters'}},
#    'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722750/taxonomy'}},
#    'sample': {'data': {'type': 'samples', 'id': 'ERS491757'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS491757'}},
#    'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722750/genome-properties'}}},
#   'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722750'}},
#  {'type': 'analysis-jobs',
#   'id': 'MGYA00722751',
#   'attributes': {'analysis-status': 'completed',
#    'pipeline-version': '5.0',
#    'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#      'value': '3070737'},
#     {'key': 'Nucleotide sequences after format-specific filtering',
#      'value': '1666704'},
#     {'key': 'Nucleotide sequences after length filtering', 'value': '1666704'},
#     {'key': 'Nucleotide sequences after undetermined bases filtering',
#      'value': '1666704'},
#     {'key': 'Predicted LSU sequences', 'value': '1'},
#     {'key': 'Predicted SSU sequences', 'value': '1665884'}],
#    'experiment-type': 'amplicon',
#    'accession': 'MGYA00722751',
#    'is-private': False,
#    'last-update': '2024-02-28T22:12:27.280406',
#    'mgx-accession': 'MGX0000894',
#    'complete-time': '2024-02-28T22:12:26',
#    'instrument-platform': 'ILLUMINA',
#    'instrument-model': 'Illumina Genome Analyzer IIx'},
#   'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722751/go-terms'}},
#    'run': {'data': {'type': 'runs', 'id': 'ERR562686'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR562686'}},
#    'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722751/downloads'}},
#    'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722751/go-slim'}},
#    'assembly': {'data': None},
#    'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722751/interpro-identifiers'}},
#    'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722751/taxonomy/unite'}},
#    'study': {'data': {'type': 'studies', 'id': 'MGYS00002392'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392'}},
#    'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722751/taxonomy/ssu'}},
#    'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722751/taxonomy/lsu'}},
#    'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722751/taxonomy/itsonedb'}},
#    'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722751/antismash-gene-clusters'}},
#    'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722751/taxonomy'}},
#    'sample': {'data': {'type': 'samples', 'id': 'ERS489263'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS489263'}},
#    'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722751/genome-properties'}}},
#   'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722751'}},
#  {'type': 'analysis-jobs',
#   'id': 'MGYA00722752',
#   'attributes': {'analysis-status': 'completed',
#    'pipeline-version': '5.0',
#    'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#      'value': '2457695'},
#     {'key': 'Nucleotide sequences after format-specific filtering',
#      'value': '1609585'},
#     {'key': 'Nucleotide sequences after length filtering', 'value': '1609585'},
#     {'key': 'Nucleotide sequences after undetermined bases filtering',
#      'value': '1609585'},
#     {'key': 'Predicted LSU sequences', 'value': '0'},
#     {'key': 'Predicted SSU sequences', 'value': '1604743'}],
#    'experiment-type': 'amplicon',
#    'accession': 'MGYA00722752',
#    'is-private': False,
#    'last-update': '2024-02-28T22:12:42.365767',
#    'mgx-accession': 'MGX0000895',
#    'complete-time': '2024-02-28T22:12:41',
#    'instrument-platform': 'ILLUMINA',
#    'instrument-model': 'Illumina Genome Analyzer IIx'},
#   'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722752/go-terms'}},
#    'run': {'data': {'type': 'runs', 'id': 'ERR562685'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR562685'}},
#    'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722752/downloads'}},
#    'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722752/go-slim'}},
#    'assembly': {'data': None},
#    'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722752/interpro-identifiers'}},
#    'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722752/taxonomy/unite'}},
#    'study': {'data': {'type': 'studies', 'id': 'MGYS00002392'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392'}},
#    'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722752/taxonomy/ssu'}},
#    'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722752/taxonomy/lsu'}},
#    'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722752/taxonomy/itsonedb'}},
#    'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722752/antismash-gene-clusters'}},
#    'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722752/taxonomy'}},
#    'sample': {'data': {'type': 'samples', 'id': 'ERS492950'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS492950'}},
#    'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722752/genome-properties'}}},
#   'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722752'}},
#  {'type': 'analysis-jobs',
#   'id': 'MGYA00722753',
#   'attributes': {'analysis-status': 'completed',
#    'pipeline-version': '5.0',
#    'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#      'value': '2115319'},
#     {'key': 'Nucleotide sequences after format-specific filtering',
#      'value': '1494402'},
#     {'key': 'Nucleotide sequences after length filtering', 'value': '1494402'},
#     {'key': 'Nucleotide sequences after undetermined bases filtering',
#      'value': '1494402'},
#     {'key': 'Predicted LSU sequences', 'value': '2'},
#     {'key': 'Predicted SSU sequences', 'value': '1493983'}],
#    'experiment-type': 'amplicon',
#    'accession': 'MGYA00722753',
#    'is-private': False,
#    'last-update': '2024-02-28T22:13:00.423425',
#    'mgx-accession': 'MGX0000896',
#    'complete-time': '2024-02-28T22:12:59',
#    'instrument-platform': 'ILLUMINA',
#    'instrument-model': 'Illumina Genome Analyzer IIx'},
#   'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722753/go-terms'}},
#    'run': {'data': {'type': 'runs', 'id': 'ERR562682'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR562682'}},
#    'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722753/downloads'}},
#    'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722753/go-slim'}},
#    'assembly': {'data': None},
#    'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722753/interpro-identifiers'}},
#    'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722753/taxonomy/unite'}},
#    'study': {'data': {'type': 'studies', 'id': 'MGYS00002392'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392'}},
#    'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722753/taxonomy/ssu'}},
#    'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722753/taxonomy/lsu'}},
#    'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722753/taxonomy/itsonedb'}},
#    'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722753/antismash-gene-clusters'}},
#    'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722753/taxonomy'}},
#    'sample': {'data': {'type': 'samples', 'id': 'ERS490564'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS490564'}},
#    'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722753/genome-properties'}}},
#   'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722753'}},
#  {'type': 'analysis-jobs',
#   'id': 'MGYA00722754',
#   'attributes': {'analysis-status': 'completed',
#    'pipeline-version': '5.0',
#    'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#      'value': '1563541'},
#     {'key': 'Nucleotide sequences after format-specific filtering',
#      'value': '1133746'},
#     {'key': 'Nucleotide sequences after length filtering', 'value': '1133746'},
#     {'key': 'Nucleotide sequences after undetermined bases filtering',
#      'value': '1133746'},
#     {'key': 'Predicted LSU sequences', 'value': '1'},
#     {'key': 'Predicted SSU sequences', 'value': '1129962'}],
#    'experiment-type': 'amplicon',
#    'accession': 'MGYA00722754',
#    'is-private': False,
#    'last-update': '2024-02-28T22:13:14.095355',
#    'mgx-accession': 'MGX0000897',
#    'complete-time': '2024-02-28T22:13:13',
#    'instrument-platform': 'ILLUMINA',
#    'instrument-model': 'Illumina Genome Analyzer IIx'},
#   'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722754/go-terms'}},
#    'run': {'data': {'type': 'runs', 'id': 'ERR562678'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR562678'}},
#    'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722754/downloads'}},
#    'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722754/go-slim'}},
#    'assembly': {'data': None},
#    'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722754/interpro-identifiers'}},
#    'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722754/taxonomy/unite'}},
#    'study': {'data': {'type': 'studies', 'id': 'MGYS00002392'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392'}},
#    'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722754/taxonomy/ssu'}},
#    'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722754/taxonomy/lsu'}},
#    'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722754/taxonomy/itsonedb'}},
#    'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722754/antismash-gene-clusters'}},
#    'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722754/taxonomy'}},
#    'sample': {'data': {'type': 'samples', 'id': 'ERS488609'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS488609'}},
#    'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722754/genome-properties'}}},
#   'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722754'}},
#  {'type': 'analysis-jobs',
#   'id': 'MGYA00722755',
#   'attributes': {'analysis-status': 'completed',
#    'pipeline-version': '5.0',
#    'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#      'value': '2433660'},
#     {'key': 'Nucleotide sequences after format-specific filtering',
#      'value': '1162089'},
#     {'key': 'Nucleotide sequences after length filtering', 'value': '1162089'},
#     {'key': 'Nucleotide sequences after undetermined bases filtering',
#      'value': '1162089'},
#     {'key': 'Predicted LSU sequences', 'value': '0'},
#     {'key': 'Predicted SSU sequences', 'value': '1161657'}],
#    'experiment-type': 'amplicon',
#    'accession': 'MGYA00722755',
#    'is-private': False,
#    'last-update': '2024-02-28T22:13:32.738474',
#    'mgx-accession': 'MGX0000898',
#    'complete-time': '2024-02-28T22:13:31',
#    'instrument-platform': 'ILLUMINA',
#    'instrument-model': 'Illumina Genome Analyzer IIx'},
#   'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722755/go-terms'}},
#    'run': {'data': {'type': 'runs', 'id': 'ERR562676'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR562676'}},
#    'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722755/downloads'}},
#    'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722755/go-slim'}},
#    'assembly': {'data': None},
#    'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722755/interpro-identifiers'}},
#    'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722755/taxonomy/unite'}},
#    'study': {'data': {'type': 'studies', 'id': 'MGYS00002392'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392'}},
#    'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722755/taxonomy/ssu'}},
#    'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722755/taxonomy/lsu'}},
#    'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722755/taxonomy/itsonedb'}},
#    'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722755/antismash-gene-clusters'}},
#    'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722755/taxonomy'}},
#    'sample': {'data': {'type': 'samples', 'id': 'ERS491904'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS491904'}},
#    'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722755/genome-properties'}}},
#   'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722755'}},
#  {'type': 'analysis-jobs',
#   'id': 'MGYA00722756',
#   'attributes': {'analysis-status': 'completed',
#    'pipeline-version': '5.0',
#    'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#      'value': '2400639'},
#     {'key': 'Nucleotide sequences after format-specific filtering',
#      'value': '1584359'},
#     {'key': 'Nucleotide sequences after length filtering', 'value': '1584359'},
#     {'key': 'Nucleotide sequences after undetermined bases filtering',
#      'value': '1584359'},
#     {'key': 'Predicted LSU sequences', 'value': '2'},
#     {'key': 'Predicted SSU sequences', 'value': '1582382'}],
#    'experiment-type': 'amplicon',
#    'accession': 'MGYA00722756',
#    'is-private': False,
#    'last-update': '2024-02-28T22:13:47.173780',
#    'mgx-accession': 'MGX0000899',
#    'complete-time': '2024-02-28T22:13:46',
#    'instrument-platform': 'ILLUMINA',
#    'instrument-model': 'Illumina Genome Analyzer IIx'},
#   'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722756/go-terms'}},
#    'run': {'data': {'type': 'runs', 'id': 'ERR562675'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR562675'}},
#    'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722756/downloads'}},
#    'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722756/go-slim'}},
#    'assembly': {'data': None},
#    'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722756/interpro-identifiers'}},
#    'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722756/taxonomy/unite'}},
#    'study': {'data': {'type': 'studies', 'id': 'MGYS00002392'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392'}},
#    'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722756/taxonomy/ssu'}},
#    'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722756/taxonomy/lsu'}},
#    'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722756/taxonomy/itsonedb'}},
#    'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722756/antismash-gene-clusters'}},
#    'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722756/taxonomy'}},
#    'sample': {'data': {'type': 'samples', 'id': 'ERS488453'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS488453'}},
#    'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722756/genome-properties'}}},
#   'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722756'}},
#  {'type': 'analysis-jobs',
#   'id': 'MGYA00722757',
#   'attributes': {'analysis-status': 'completed',
#    'pipeline-version': '5.0',
#    'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#      'value': '2145560'},
#     {'key': 'Nucleotide sequences after format-specific filtering',
#      'value': '1355436'},
#     {'key': 'Nucleotide sequences after length filtering', 'value': '1355436'},
#     {'key': 'Nucleotide sequences after undetermined bases filtering',
#      'value': '1355436'},
#     {'key': 'Predicted LSU sequences', 'value': '2'},
#     {'key': 'Predicted SSU sequences', 'value': '1276071'}],
#    'experiment-type': 'amplicon',
#    'accession': 'MGYA00722757',
#    'is-private': False,
#    'last-update': '2024-02-28T22:14:06.132063',
#    'mgx-accession': 'MGX0000900',
#    'complete-time': '2024-02-28T22:14:05',
#    'instrument-platform': 'ILLUMINA',
#    'instrument-model': 'Illumina Genome Analyzer IIx'},
#   'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722757/go-terms'}},
#    'run': {'data': {'type': 'runs', 'id': 'ERR562674'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR562674'}},
#    'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722757/downloads'}},
#    'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722757/go-slim'}},
#    'assembly': {'data': None},
#    'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722757/interpro-identifiers'}},
#    'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722757/taxonomy/unite'}},
#    'study': {'data': {'type': 'studies', 'id': 'MGYS00002392'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392'}},
#    'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722757/taxonomy/ssu'}},
#    'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722757/taxonomy/lsu'}},
#    'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722757/taxonomy/itsonedb'}},
#    'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722757/antismash-gene-clusters'}},
#    'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722757/taxonomy'}},
#    'sample': {'data': {'type': 'samples', 'id': 'ERS477937'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS477937'}},
#    'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722757/genome-properties'}}},
#   'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722757'}},
#  {'type': 'analysis-jobs',
#   'id': 'MGYA00722758',
#   'attributes': {'analysis-status': 'completed',
#    'pipeline-version': '5.0',
#    'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#      'value': '5039782'},
#     {'key': 'Nucleotide sequences after format-specific filtering',
#      'value': '2622644'},
#     {'key': 'Nucleotide sequences after length filtering', 'value': '2622644'},
#     {'key': 'Nucleotide sequences after undetermined bases filtering',
#      'value': '2622644'},
#     {'key': 'Predicted LSU sequences', 'value': '0'},
#     {'key': 'Predicted SSU sequences', 'value': '2331060'}],
#    'experiment-type': 'amplicon',
#    'accession': 'MGYA00722758',
#    'is-private': False,
#    'last-update': '2024-02-28T22:14:22.828408',
#    'mgx-accession': 'MGX0000901',
#    'complete-time': '2024-02-28T22:14:22',
#    'instrument-platform': 'ILLUMINA',
#    'instrument-model': 'Illumina Genome Analyzer IIx'},
#   'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722758/go-terms'}},
#    'run': {'data': {'type': 'runs', 'id': 'ERR562673'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR562673'}},
#    'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722758/downloads'}},
#    'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722758/go-slim'}},
#    'assembly': {'data': None},
#    'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722758/interpro-identifiers'}},
#    'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722758/taxonomy/unite'}},
#    'study': {'data': {'type': 'studies', 'id': 'MGYS00002392'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392'}},
#    'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722758/taxonomy/ssu'}},
#    'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722758/taxonomy/lsu'}},
#    'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722758/taxonomy/itsonedb'}},
#    'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722758/antismash-gene-clusters'}},
#    'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722758/taxonomy'}},
#    'sample': {'data': {'type': 'samples', 'id': 'ERS490021'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS490021'}},
#    'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722758/genome-properties'}}},
#   'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722758'}},
#  {'type': 'analysis-jobs',
#   'id': 'MGYA00722759',
#   'attributes': {'analysis-status': 'completed',
#    'pipeline-version': '5.0',
#    'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#      'value': '2806143'},
#     {'key': 'Nucleotide sequences after format-specific filtering',
#      'value': '1022691'},
#     {'key': 'Nucleotide sequences after length filtering', 'value': '1022691'},
#     {'key': 'Nucleotide sequences after undetermined bases filtering',
#      'value': '1022691'},
#     {'key': 'Predicted LSU sequences', 'value': '1'},
#     {'key': 'Predicted SSU sequences', 'value': '1022148'}],
#    'experiment-type': 'amplicon',
#    'accession': 'MGYA00722759',
#    'is-private': False,
#    'last-update': '2024-02-28T22:14:38.616497',
#    'mgx-accession': 'MGX0000902',
#    'complete-time': '2024-02-28T22:14:37',
#    'instrument-platform': 'ILLUMINA',
#    'instrument-model': 'Illumina Genome Analyzer IIx'},
#   'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722759/go-terms'}},
#    'run': {'data': {'type': 'runs', 'id': 'ERR562669'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR562669'}},
#    'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722759/downloads'}},
#    'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722759/go-slim'}},
#    'assembly': {'data': None},
#    'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722759/interpro-identifiers'}},
# ...
#    'assembly': {'data': None},
#    'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722762/interpro-identifiers'}},
#    'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722762/taxonomy/unite'}},
#    'study': {'data': {'type': 'studies', 'id': 'MGYS00002392'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392'}},
#    'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722762/taxonomy/ssu'}},
#    'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722762/taxonomy/lsu'}},
#    'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722762/taxonomy/itsonedb'}},
#    'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722762/antismash-gene-clusters'}},
#    'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722762/taxonomy'}},
#    'sample': {'data': {'type': 'samples', 'id': 'ERS490256'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS490256'}},
#    'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722762/genome-properties'}}},
#   'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722762'}},
#  {'type': 'analysis-jobs',
#   'id': 'MGYA00722763',
#   'attributes': {'analysis-status': 'completed',
#    'pipeline-version': '5.0',
#    'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#      'value': '3062336'},
#     {'key': 'Nucleotide sequences after format-specific filtering',
#      'value': '1188496'},
#     {'key': 'Nucleotide sequences after length filtering', 'value': '1188496'},
#     {'key': 'Nucleotide sequences after undetermined bases filtering',
#      'value': '1188496'},
#     {'key': 'Predicted LSU sequences', 'value': '0'},
#     {'key': 'Predicted SSU sequences', 'value': '1177429'}],
#    'experiment-type': 'amplicon',
#    'accession': 'MGYA00722763',
#    'is-private': False,
#    'last-update': '2024-02-28T22:15:37.201003',
#    'mgx-accession': 'MGX0000906',
#    'complete-time': '2024-02-28T22:15:36',
#    'instrument-platform': 'ILLUMINA',
#    'instrument-model': 'Illumina Genome Analyzer IIx'},
#   'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722763/go-terms'}},
#    'run': {'data': {'type': 'runs', 'id': 'ERR562647'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR562647'}},
#    'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722763/downloads'}},
#    'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722763/go-slim'}},
#    'assembly': {'data': None},
#    'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722763/interpro-identifiers'}},
#    'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722763/taxonomy/unite'}},
#    'study': {'data': {'type': 'studies', 'id': 'MGYS00002392'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392'}},
#    'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722763/taxonomy/ssu'}},
#    'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722763/taxonomy/lsu'}},
#    'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722763/taxonomy/itsonedb'}},
#    'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722763/antismash-gene-clusters'}},
#    'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722763/taxonomy'}},
#    'sample': {'data': {'type': 'samples', 'id': 'ERS490448'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS490448'}},
#    'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722763/genome-properties'}}},
#   'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722763'}},
#  {'type': 'analysis-jobs',
#   'id': 'MGYA00722764',
#   'attributes': {'analysis-status': 'completed',
#    'pipeline-version': '5.0',
#    'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#      'value': '2431221'},
#     {'key': 'Nucleotide sequences after format-specific filtering',
#      'value': '1237547'},
#     {'key': 'Nucleotide sequences after length filtering', 'value': '1237547'},
#     {'key': 'Nucleotide sequences after undetermined bases filtering',
#      'value': '1237547'},
#     {'key': 'Predicted LSU sequences', 'value': '0'},
#     {'key': 'Predicted SSU sequences', 'value': '1229751'}],
#    'experiment-type': 'amplicon',
#    'accession': 'MGYA00722764',
#    'is-private': False,
#    'last-update': '2024-02-28T22:15:54.216674',
#    'mgx-accession': 'MGX0000907',
#    'complete-time': '2024-02-28T22:15:53',
#    'instrument-platform': 'ILLUMINA',
#    'instrument-model': 'Illumina Genome Analyzer IIx'},
#   'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722764/go-terms'}},
#    'run': {'data': {'type': 'runs', 'id': 'ERR562646'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR562646'}},
#    'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722764/downloads'}},
#    'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722764/go-slim'}},
#    'assembly': {'data': None},
#    'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722764/interpro-identifiers'}},
#    'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722764/taxonomy/unite'}},
#    'study': {'data': {'type': 'studies', 'id': 'MGYS00002392'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392'}},
#    'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722764/taxonomy/ssu'}},
#    'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722764/taxonomy/lsu'}},
#    'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722764/taxonomy/itsonedb'}},
#    'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722764/antismash-gene-clusters'}},
#    'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722764/taxonomy'}},
#    'sample': {'data': {'type': 'samples', 'id': 'ERS489053'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS489053'}},
#    'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722764/genome-properties'}}},
#   'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722764'}},
#  {'type': 'analysis-jobs',
#   'id': 'MGYA00722765',
#   'attributes': {'analysis-status': 'completed',
#    'pipeline-version': '5.0',
#    'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#      'value': '2698634'},
#     {'key': 'Nucleotide sequences after format-specific filtering',
#      'value': '1365330'},
#     {'key': 'Nucleotide sequences after length filtering', 'value': '1365330'},
#     {'key': 'Nucleotide sequences after undetermined bases filtering',
#      'value': '1365330'},
#     {'key': 'Predicted LSU sequences', 'value': '0'},
#     {'key': 'Predicted SSU sequences', 'value': '1361829'}],
#    'experiment-type': 'amplicon',
#    'accession': 'MGYA00722765',
#    'is-private': False,
#    'last-update': '2024-02-28T22:16:12.884384',
#    'mgx-accession': 'MGX0000908',
#    'complete-time': '2024-02-28T22:16:12',
#    'instrument-platform': 'ILLUMINA',
#    'instrument-model': 'Illumina Genome Analyzer IIx'},
#   'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722765/go-terms'}},
#    'run': {'data': {'type': 'runs', 'id': 'ERR562643'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR562643'}},
#    'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722765/downloads'}},
#    'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722765/go-slim'}},
#    'assembly': {'data': None},
#    'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722765/interpro-identifiers'}},
#    'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722765/taxonomy/unite'}},
#    'study': {'data': {'type': 'studies', 'id': 'MGYS00002392'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392'}},
#    'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722765/taxonomy/ssu'}},
#    'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722765/taxonomy/lsu'}},
#    'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722765/taxonomy/itsonedb'}},
#    'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722765/antismash-gene-clusters'}},
#    'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722765/taxonomy'}},
#    'sample': {'data': {'type': 'samples', 'id': 'ERS488338'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS488338'}},
#    'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722765/genome-properties'}}},
#   'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722765'}},
#  {'type': 'analysis-jobs',
#   'id': 'MGYA00722766',
#   'attributes': {'analysis-status': 'completed',
#    'pipeline-version': '5.0',
#    'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#      'value': '3343823'},
#     {'key': 'Nucleotide sequences after format-specific filtering',
#      'value': '1281709'},
#     {'key': 'Nucleotide sequences after length filtering', 'value': '1281709'},
#     {'key': 'Nucleotide sequences after undetermined bases filtering',
#      'value': '1281709'},
#     {'key': 'Predicted LSU sequences', 'value': '0'},
#     {'key': 'Predicted SSU sequences', 'value': '1265829'}],
#    'experiment-type': 'amplicon',
#    'accession': 'MGYA00722766',
#    'is-private': False,
#    'last-update': '2024-02-28T22:16:29.836529',
#    'mgx-accession': 'MGX0000909',
#    'complete-time': '2024-02-28T22:16:28',
#    'instrument-platform': 'ILLUMINA',
#    'instrument-model': 'Illumina Genome Analyzer IIx'},
#   'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722766/go-terms'}},
#    'run': {'data': {'type': 'runs', 'id': 'ERR562641'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR562641'}},
#    'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722766/downloads'}},
#    'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722766/go-slim'}},
#    'assembly': {'data': None},
#    'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722766/interpro-identifiers'}},
#    'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722766/taxonomy/unite'}},
#    'study': {'data': {'type': 'studies', 'id': 'MGYS00002392'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392'}},
#    'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722766/taxonomy/ssu'}},
#    'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722766/taxonomy/lsu'}},
#    'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722766/taxonomy/itsonedb'}},
#    'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722766/antismash-gene-clusters'}},
#    'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722766/taxonomy'}},
#    'sample': {'data': {'type': 'samples', 'id': 'ERS490198'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS490198'}},
#    'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722766/genome-properties'}}},
#   'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722766'}},
#  {'type': 'analysis-jobs',
#   'id': 'MGYA00722767',
#   'attributes': {'analysis-status': 'completed',
#    'pipeline-version': '5.0',
#    'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#      'value': '2377044'},
#     {'key': 'Nucleotide sequences after format-specific filtering',
#      'value': '1346516'},
#     {'key': 'Nucleotide sequences after length filtering', 'value': '1346516'},
#     {'key': 'Nucleotide sequences after undetermined bases filtering',
#      'value': '1346516'},
#     {'key': 'Predicted LSU sequences', 'value': '0'},
#     {'key': 'Predicted SSU sequences', 'value': '1332749'}],
#    'experiment-type': 'amplicon',
#    'accession': 'MGYA00722767',
#    'is-private': False,
#    'last-update': '2024-02-28T22:16:45.696354',
#    'mgx-accession': 'MGX0000910',
#    'complete-time': '2024-02-28T22:16:44',
#    'instrument-platform': 'ILLUMINA',
#    'instrument-model': 'Illumina Genome Analyzer IIx'},
#   'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722767/go-terms'}},
#    'run': {'data': {'type': 'runs', 'id': 'ERR562640'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR562640'}},
#    'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722767/downloads'}},
#    'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722767/go-slim'}},
#    'assembly': {'data': None},
#    'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722767/interpro-identifiers'}},
#    'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722767/taxonomy/unite'}},
#    'study': {'data': {'type': 'studies', 'id': 'MGYS00002392'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392'}},
#    'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722767/taxonomy/ssu'}},
#    'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722767/taxonomy/lsu'}},
#    'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722767/taxonomy/itsonedb'}},
#    'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722767/antismash-gene-clusters'}},
#    'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722767/taxonomy'}},
#    'sample': {'data': {'type': 'samples', 'id': 'ERS488832'},
#     'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS488832'}},
#    'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722767/genome-properties'}}},
#   'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722767'}}]

# %%
data = pd.json_normalize(r.json()['data'])

# %%
data.shape
# Out:
# (25, 35)

# %%
data.head(2)
# Out:
#             type            id attributes.analysis-status  \
# 0  analysis-jobs  MGYA00722743                  completed
# 1  analysis-jobs  MGYA00722744                  completed
#
#   attributes.pipeline-version  \
# 0                         5.0
# 1                         5.0
#
#                                                                                                                                                                                                                                                                                                                                                                                                           attributes.analysis-summary  \
# 0  [{'key': 'Submitted nucleotide sequences', 'value': '2050402'}, {'key': 'Nucleotide sequences after format-specific filtering', 'value': '1357633'}, {'key': 'Nucleotide sequences after length filtering', 'value': '1357633'}, {'key': 'Nucleotide sequences after undetermined bases filtering', 'value': '1357633'}, {'key': 'Predicted LSU sequences', 'value': '1'}, {'key': 'Predicted SSU sequences', 'value': '1355389'}]
# 1  [{'key': 'Submitted nucleotide sequences', 'value': '2899522'}, {'key': 'Nucleotide sequences after format-specific filtering', 'value': '1261859'}, {'key': 'Nucleotide sequences after length filtering', 'value': '1261859'}, {'key': 'Nucleotide sequences after undetermined bases filtering', 'value': '1261859'}, {'key': 'Predicted LSU sequences', 'value': '0'}, {'key': 'Predicted SSU sequences', 'value': '1261348'}]
#
#   attributes.experiment-type attributes.accession  attributes.is-private  \
# 0                   amplicon         MGYA00722743                  False
# 1                   amplicon         MGYA00722744                  False
#
#        attributes.last-update attributes.mgx-accession  \
# 0  2024-02-28T22:10:08.862460               MGX0000886
# 1  2024-02-28T22:10:26.857803               MGX0000887
#
#   attributes.complete-time attributes.instrument-platform  \
# 0      2024-02-28T22:10:07                       ILLUMINA
# 1      2024-02-28T22:10:26                       ILLUMINA
#
#     attributes.instrument-model  \
# 0  Illumina Genome Analyzer IIx
# 1  Illumina Genome Analyzer IIx
#
#                                        relationships.go-terms.links.related  \
# 0  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743/go-terms
# 1  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744/go-terms
#
#   relationships.run.data.type relationships.run.data.id  \
# 0                        runs                 ERR566174
# 1                        runs                 ERR562730
#
#                             relationships.run.links.related  \
# 0  https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR566174
# 1  https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR562730
#
#                                        relationships.downloads.links.related  \
# 0  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743/downloads
# 1  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744/downloads
#
#                                        relationships.go-slim.links.related  \
# 0  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743/go-slim
# 1  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744/go-slim
#
#   relationships.assembly.data  \
# 0                        None
# 1                        None
#
#                                        relationships.interpro-identifiers.links.related  \
# 0  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743/interpro-identifiers
# 1  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744/interpro-identifiers
#
#                                     relationships.taxonomy-itsunite.links.related  \
# 0  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743/taxonomy/unite
# 1  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744/taxonomy/unite
#
#   relationships.study.data.type relationships.study.data.id  \
# 0                       studies                MGYS00002392
# 1                       studies                MGYS00002392
#
#                                 relationships.study.links.related  \
# 0  https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392
# 1  https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002392
#
#                                        relationships.taxonomy-ssu.links.related  \
# 0  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743/taxonomy/ssu
# 1  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744/taxonomy/ssu
#
#                                        relationships.taxonomy-lsu.links.related  \
# 0  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743/taxonomy/lsu
# 1  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744/taxonomy/lsu
#
#                                        relationships.taxonomy-itsonedb.links.related  \
# 0  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743/taxonomy/itsonedb
# 1  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744/taxonomy/itsonedb
#
#                                        relationships.antismash-gene-clusters.links.related  \
# 0  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743/antismash-gene-clusters
# 1  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744/antismash-gene-clusters
#
#                                        relationships.taxonomy.links.related  \
# 0  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743/taxonomy
# 1  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744/taxonomy
#
#   relationships.sample.data.type relationships.sample.data.id  \
# 0                        samples                    ERS506046
# 1                        samples                    ERS492004
#
#                             relationships.sample.links.related  \
# 0  https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS506046
# 1  https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS492004
#
#                                        relationships.genome-properties.links.related  \
# 0  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743/genome-properties
# 1  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744/genome-properties
#
#                                                         links.self
# 0  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722743
# 1  https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00722744

# %%
r = requests.get(f"https://www.ebi.ac.uk/metagenomics/api/v1/pipelines/5.0/analyses")
r.json()
# Out:
# {'links': {'first': 'https://www.ebi.ac.uk/metagenomics/api/v1/pipelines/5.0/analyses?page=1',
#   'last': 'https://www.ebi.ac.uk/metagenomics/api/v1/pipelines/5.0/analyses?page=9113',
#   'next': 'https://www.ebi.ac.uk/metagenomics/api/v1/pipelines/5.0/analyses?page=2',
#   'prev': None},
#  'data': [{'type': 'analysis-jobs',
#    'id': 'MGYA00383253',
#    'attributes': {'analysis-status': 'completed',
#     'pipeline-version': '5.0',
#     'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#       'value': '55799'},
#      {'key': 'Nucleotide sequences after format-specific filtering',
#       'value': '55789'},
#      {'key': 'Nucleotide sequences after length filtering', 'value': '55789'},
#      {'key': 'Nucleotide sequences after undetermined bases filtering',
#       'value': '55789'},
#      {'key': 'Predicted SSU sequences', 'value': '0'},
#      {'key': 'Predicted LSU sequences', 'value': '461'}],
#     'experiment-type': 'amplicon',
#     'accession': 'MGYA00383253',
#     'is-private': False,
#     'last-update': '2024-01-29T15:29:19.757516',
#     'mgx-accession': None,
#     'complete-time': '2020-06-11T10:51:27',
#     'instrument-platform': 'ILLUMINA',
#     'instrument-model': 'Illumina MiSeq'},
#    'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253/go-terms'}},
#     'run': {'data': {'type': 'runs', 'id': 'ERR2237853'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR2237853'}},
#     'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253/downloads'}},
#     'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253/go-slim'}},
#     'assembly': {'data': None},
#     'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253/interpro-identifiers'}},
#     'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253/taxonomy/unite'}},
#     'study': {'data': {'type': 'studies', 'id': 'MGYS00002115'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002115'}},
#     'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253/taxonomy/ssu'}},
#     'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253/taxonomy/lsu'}},
#     'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253/taxonomy/itsonedb'}},
#     'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253/antismash-gene-clusters'}},
#     'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253/taxonomy'}},
#     'sample': {'data': {'type': 'samples', 'id': 'ERS2075820'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS2075820'}},
#     'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253/genome-properties'}}},
#    'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383253'}},
#   {'type': 'analysis-jobs',
#    'id': 'MGYA00383254',
#    'attributes': {'analysis-status': 'completed',
#     'pipeline-version': '5.0',
#     'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#       'value': '1092543'},
#      {'key': 'Nucleotide sequences after format-specific filtering',
#       'value': '1092543'},
#      {'key': 'Nucleotide sequences after length filtering',
#       'value': '1092543'},
#      {'key': 'Nucleotide sequences after undetermined bases filtering',
#       'value': '1092543'},
#      {'key': 'Predicted CDS', 'value': '1312585'},
#      {'key': 'Predicted CDS with InterProScan match', 'value': '781037'},
#      {'key': 'Total InterProScan matches', 'value': '1750368'},
#      {'key': 'Contigs with InterProScan match', 'value': '688609'},
#      {'key': 'Contigs with predicted CDS', 'value': '1078198'},
#      {'key': 'Contigs with predicted RNA', 'value': '785'}],
#     'experiment-type': 'assembly',
#     'accession': 'MGYA00383254',
#     'is-private': False,
#     'last-update': '2024-01-29T15:29:19.757516',
#     'mgx-accession': 'MGX0003555',
#     'complete-time': '2019-11-11T12:36:17',
#     'instrument-platform': 'ILLUMINA',
#     'instrument-model': 'Illumina HiSeq 2000'},
#    'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383254/go-terms'}},
#     'run': {'data': None},
#     'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383254/downloads'}},
#     'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383254/go-slim'}},
#     'assembly': {'data': {'type': 'assemblies', 'id': 'ERZ1749741'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/assemblies/ERZ1749741'}},
#     'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383254/interpro-identifiers'}},
#     'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383254/taxonomy/unite'}},
#     'study': {'data': {'type': 'studies', 'id': 'MGYS00002008'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002008'}},
#     'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383254/taxonomy/ssu'}},
#     'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383254/taxonomy/lsu'}},
#     'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383254/taxonomy/itsonedb'}},
#     'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383254/antismash-gene-clusters'}},
#     'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383254/taxonomy'}},
#     'sample': {'data': {'type': 'samples', 'id': 'ERS487899'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS487899'}},
#     'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383254/genome-properties'}}},
#    'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00383254'}},
#   {'type': 'analysis-jobs',
#    'id': 'MGYA00429279',
#    'attributes': {'analysis-status': 'completed',
#     'pipeline-version': '5.0',
#     'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#       'value': '905'},
#      {'key': 'Nucleotide sequences after format-specific filtering',
#       'value': '889'},
#      {'key': 'Nucleotide sequences after length filtering', 'value': '889'},
#      {'key': 'Nucleotide sequences after undetermined bases filtering',
#       'value': '889'},
#      {'key': 'Predicted SSU sequences', 'value': '0'},
#      {'key': 'Predicted LSU sequences', 'value': '0'}],
#     'experiment-type': 'amplicon',
#     'accession': 'MGYA00429279',
#     'is-private': False,
#     'last-update': '2024-01-29T15:29:19.757516',
#     'mgx-accession': None,
#     'complete-time': '2020-11-05T20:43:04',
#     'instrument-platform': 'ILLUMINA',
#     'instrument-model': 'Illumina MiSeq'},
#    'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429279/go-terms'}},
#     'run': {'data': {'type': 'runs', 'id': 'SRR6843879'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/SRR6843879'}},
#     'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429279/downloads'}},
#     'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429279/go-slim'}},
#     'assembly': {'data': None},
#     'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429279/interpro-identifiers'}},
#     'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429279/taxonomy/unite'}},
#     'study': {'data': {'type': 'studies', 'id': 'MGYS00005251'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00005251'}},
#     'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429279/taxonomy/ssu'}},
#     'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429279/taxonomy/lsu'}},
#     'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429279/taxonomy/itsonedb'}},
#     'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429279/antismash-gene-clusters'}},
#     'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429279/taxonomy'}},
#     'sample': {'data': {'type': 'samples', 'id': 'SRS3051409'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS3051409'}},
#     'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429279/genome-properties'}}},
#    'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429279'}},
#   {'type': 'analysis-jobs',
#    'id': 'MGYA00429280',
#    'attributes': {'analysis-status': 'completed',
#     'pipeline-version': '5.0',
#     'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#       'value': '931'},
#      {'key': 'Nucleotide sequences after format-specific filtering',
#       'value': '899'},
#      {'key': 'Nucleotide sequences after length filtering', 'value': '899'},
#      {'key': 'Nucleotide sequences after undetermined bases filtering',
#       'value': '899'},
#      {'key': 'Predicted SSU sequences', 'value': '1'},
#      {'key': 'Predicted LSU sequences', 'value': '0'}],
#     'experiment-type': 'amplicon',
#     'accession': 'MGYA00429280',
#     'is-private': False,
#     'last-update': '2024-01-29T15:29:19.757516',
#     'mgx-accession': None,
#     'complete-time': '2020-11-05T20:43:23',
#     'instrument-platform': 'ILLUMINA',
#     'instrument-model': 'Illumina MiSeq'},
#    'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429280/go-terms'}},
#     'run': {'data': {'type': 'runs', 'id': 'SRR6843877'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/SRR6843877'}},
#     'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429280/downloads'}},
#     'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429280/go-slim'}},
#     'assembly': {'data': None},
#     'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429280/interpro-identifiers'}},
#     'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429280/taxonomy/unite'}},
#     'study': {'data': {'type': 'studies', 'id': 'MGYS00005251'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00005251'}},
#     'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429280/taxonomy/ssu'}},
#     'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429280/taxonomy/lsu'}},
#     'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429280/taxonomy/itsonedb'}},
#     'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429280/antismash-gene-clusters'}},
#     'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429280/taxonomy'}},
#     'sample': {'data': {'type': 'samples', 'id': 'SRS3051412'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS3051412'}},
#     'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429280/genome-properties'}}},
#    'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429280'}},
#   {'type': 'analysis-jobs',
#    'id': 'MGYA00429281',
#    'attributes': {'analysis-status': 'completed',
#     'pipeline-version': '5.0',
#     'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#       'value': '965'},
#      {'key': 'Nucleotide sequences after format-specific filtering',
#       'value': '939'},
#      {'key': 'Nucleotide sequences after length filtering', 'value': '939'},
#      {'key': 'Nucleotide sequences after undetermined bases filtering',
#       'value': '939'},
#      {'key': 'Predicted SSU sequences', 'value': '5'},
#      {'key': 'Predicted LSU sequences', 'value': '0'}],
#     'experiment-type': 'amplicon',
#     'accession': 'MGYA00429281',
#     'is-private': False,
#     'last-update': '2024-01-29T15:29:19.757516',
#     'mgx-accession': None,
#     'complete-time': '2020-11-05T20:04:56',
#     'instrument-platform': 'ILLUMINA',
#     'instrument-model': 'Illumina MiSeq'},
#    'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429281/go-terms'}},
#     'run': {'data': {'type': 'runs', 'id': 'SRR6843876'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/SRR6843876'}},
#     'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429281/downloads'}},
#     'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429281/go-slim'}},
#     'assembly': {'data': None},
#     'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429281/interpro-identifiers'}},
#     'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429281/taxonomy/unite'}},
#     'study': {'data': {'type': 'studies', 'id': 'MGYS00005251'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00005251'}},
#     'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429281/taxonomy/ssu'}},
#     'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429281/taxonomy/lsu'}},
#     'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429281/taxonomy/itsonedb'}},
#     'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429281/antismash-gene-clusters'}},
#     'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429281/taxonomy'}},
#     'sample': {'data': {'type': 'samples', 'id': 'SRS3051410'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS3051410'}},
#     'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429281/genome-properties'}}},
#    'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429281'}},
#   {'type': 'analysis-jobs',
#    'id': 'MGYA00429282',
#    'attributes': {'analysis-status': 'completed',
#     'pipeline-version': '5.0',
#     'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#       'value': '872'},
#      {'key': 'Nucleotide sequences after format-specific filtering',
#       'value': '837'},
#      {'key': 'Nucleotide sequences after length filtering', 'value': '837'},
#      {'key': 'Nucleotide sequences after undetermined bases filtering',
#       'value': '837'},
#      {'key': 'Predicted SSU sequences', 'value': '4'},
#      {'key': 'Predicted LSU sequences', 'value': '0'}],
#     'experiment-type': 'amplicon',
#     'accession': 'MGYA00429282',
#     'is-private': False,
#     'last-update': '2024-01-29T15:29:19.757516',
#     'mgx-accession': None,
#     'complete-time': '2020-11-05T21:30:23',
#     'instrument-platform': 'ILLUMINA',
#     'instrument-model': 'Illumina MiSeq'},
#    'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429282/go-terms'}},
#     'run': {'data': {'type': 'runs', 'id': 'SRR6843872'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/SRR6843872'}},
#     'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429282/downloads'}},
#     'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429282/go-slim'}},
#     'assembly': {'data': None},
#     'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429282/interpro-identifiers'}},
#     'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429282/taxonomy/unite'}},
#     'study': {'data': {'type': 'studies', 'id': 'MGYS00005251'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00005251'}},
#     'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429282/taxonomy/ssu'}},
#     'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429282/taxonomy/lsu'}},
#     'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429282/taxonomy/itsonedb'}},
#     'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429282/antismash-gene-clusters'}},
#     'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429282/taxonomy'}},
#     'sample': {'data': {'type': 'samples', 'id': 'SRS3051414'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS3051414'}},
#     'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429282/genome-properties'}}},
#    'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429282'}},
#   {'type': 'analysis-jobs',
#    'id': 'MGYA00429283',
#    'attributes': {'analysis-status': 'completed',
#     'pipeline-version': '5.0',
#     'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#       'value': '173961'},
#      {'key': 'Nucleotide sequences after format-specific filtering',
#       'value': '162050'},
#      {'key': 'Nucleotide sequences after length filtering', 'value': '162050'},
#      {'key': 'Nucleotide sequences after undetermined bases filtering',
#       'value': '162050'},
#      {'key': 'Predicted SSU sequences', 'value': '162005'},
#      {'key': 'Predicted LSU sequences', 'value': '4'}],
#     'experiment-type': 'amplicon',
#     'accession': 'MGYA00429283',
#     'is-private': False,
#     'last-update': '2024-01-29T15:29:19.757516',
#     'mgx-accession': None,
#     'complete-time': '2020-11-15T15:10:44',
#     'instrument-platform': 'ILLUMINA',
#     'instrument-model': 'Illumina HiSeq 2500'},
#    'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429283/go-terms'}},
#     'run': {'data': {'type': 'runs', 'id': 'SRR5586556'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/SRR5586556'}},
#     'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429283/downloads'}},
#     'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429283/go-slim'}},
#     'assembly': {'data': None},
#     'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429283/interpro-identifiers'}},
#     'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429283/taxonomy/unite'}},
#     'study': {'data': {'type': 'studies', 'id': 'MGYS00005169'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00005169'}},
#     'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429283/taxonomy/ssu'}},
#     'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429283/taxonomy/lsu'}},
#     'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429283/taxonomy/itsonedb'}},
#     'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429283/antismash-gene-clusters'}},
#     'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429283/taxonomy'}},
#     'sample': {'data': {'type': 'samples', 'id': 'SRS2217638'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS2217638'}},
#     'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429283/genome-properties'}}},
#    'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429283'}},
#   {'type': 'analysis-jobs',
#    'id': 'MGYA00429284',
#    'attributes': {'analysis-status': 'completed',
#     'pipeline-version': '5.0',
#     'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#       'value': '307808'},
#      {'key': 'Nucleotide sequences after format-specific filtering',
#       'value': '285952'},
#      {'key': 'Nucleotide sequences after length filtering', 'value': '285952'},
#      {'key': 'Nucleotide sequences after undetermined bases filtering',
#       'value': '285952'},
#      {'key': 'Predicted SSU sequences', 'value': '285897'},
#      {'key': 'Predicted LSU sequences', 'value': '19'}],
#     'experiment-type': 'amplicon',
#     'accession': 'MGYA00429284',
#     'is-private': False,
#     'last-update': '2024-01-29T15:29:19.757516',
#     'mgx-accession': None,
#     'complete-time': '2020-11-15T09:20:08',
#     'instrument-platform': 'ILLUMINA',
#     'instrument-model': 'Illumina HiSeq 2500'},
#    'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429284/go-terms'}},
#     'run': {'data': {'type': 'runs', 'id': 'SRR5586551'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/SRR5586551'}},
#     'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429284/downloads'}},
#     'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429284/go-slim'}},
#     'assembly': {'data': None},
#     'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429284/interpro-identifiers'}},
#     'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429284/taxonomy/unite'}},
#     'study': {'data': {'type': 'studies', 'id': 'MGYS00005169'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00005169'}},
#     'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429284/taxonomy/ssu'}},
#     'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429284/taxonomy/lsu'}},
#     'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429284/taxonomy/itsonedb'}},
#     'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429284/antismash-gene-clusters'}},
#     'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429284/taxonomy'}},
#     'sample': {'data': {'type': 'samples', 'id': 'SRS2217644'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS2217644'}},
#     'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429284/genome-properties'}}},
#    'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429284'}},
#   {'type': 'analysis-jobs',
#    'id': 'MGYA00429285',
#    'attributes': {'analysis-status': 'completed',
#     'pipeline-version': '5.0',
#     'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#       'value': '74600'},
#      {'key': 'Nucleotide sequences after format-specific filtering',
#       'value': '74581'},
#      {'key': 'Nucleotide sequences after length filtering', 'value': '74581'},
#      {'key': 'Nucleotide sequences after undetermined bases filtering',
#       'value': '74581'},
#      {'key': 'Predicted SSU sequences', 'value': '0'},
#      {'key': 'Predicted LSU sequences', 'value': '400'}],
#     'experiment-type': 'amplicon',
#     'accession': 'MGYA00429285',
#     'is-private': False,
#     'last-update': '2024-01-29T15:29:19.757516',
#     'mgx-accession': None,
#     'complete-time': '2020-03-11T11:35:39',
#     'instrument-platform': 'ILLUMINA',
#     'instrument-model': 'Illumina MiSeq'},
#    'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429285/go-terms'}},
#     'run': {'data': {'type': 'runs', 'id': 'ERR2237860'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR2237860'}},
#     'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429285/downloads'}},
#     'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429285/go-slim'}},
#     'assembly': {'data': None},
#     'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429285/interpro-identifiers'}},
#     'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429285/taxonomy/unite'}},
#     'study': {'data': {'type': 'studies', 'id': 'MGYS00002115'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002115'}},
#     'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429285/taxonomy/ssu'}},
#     'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429285/taxonomy/lsu'}},
#     'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429285/taxonomy/itsonedb'}},
#     'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429285/antismash-gene-clusters'}},
#     'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429285/taxonomy'}},
#     'sample': {'data': {'type': 'samples', 'id': 'ERS2075827'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS2075827'}},
#     'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429285/genome-properties'}}},
#    'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429285'}},
#   {'type': 'analysis-jobs',
#    'id': 'MGYA00429286',
#    'attributes': {'analysis-status': 'completed',
#     'pipeline-version': '5.0',
#     'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#       'value': '74114'},
#      {'key': 'Nucleotide sequences after format-specific filtering',
#       'value': '74090'},
#      {'key': 'Nucleotide sequences after length filtering', 'value': '74090'},
#      {'key': 'Nucleotide sequences after undetermined bases filtering',
#       'value': '74090'},
#      {'key': 'Predicted SSU sequences', 'value': '0'},
#      {'key': 'Predicted LSU sequences', 'value': '283'}],
#     'experiment-type': 'amplicon',
#     'accession': 'MGYA00429286',
#     'is-private': False,
#     'last-update': '2024-01-29T15:29:19.757516',
#     'mgx-accession': None,
#     'complete-time': '2020-03-11T11:42:55',
#     'instrument-platform': 'ILLUMINA',
#     'instrument-model': 'Illumina MiSeq'},
#    'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429286/go-terms'}},
#     'run': {'data': {'type': 'runs', 'id': 'ERR2237858'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR2237858'}},
#     'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429286/downloads'}},
#     'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429286/go-slim'}},
#     'assembly': {'data': None},
#     'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429286/interpro-identifiers'}},
#     'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429286/taxonomy/unite'}},
#     'study': {'data': {'type': 'studies', 'id': 'MGYS00002115'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002115'}},
#     'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429286/taxonomy/ssu'}},
#     'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429286/taxonomy/lsu'}},
#     'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429286/taxonomy/itsonedb'}},
#     'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429286/antismash-gene-clusters'}},
#     'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429286/taxonomy'}},
#     'sample': {'data': {'type': 'samples', 'id': 'ERS2075825'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS2075825'}},
#     'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429286/genome-properties'}}},
#    'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429286'}},
#   {'type': 'analysis-jobs',
#    'id': 'MGYA00429287',
#    'attributes': {'analysis-status': 'completed',
#     'pipeline-version': '5.0',
#     'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#       'value': '8348'},
#      {'key': 'Nucleotide sequences after format-specific filtering',
#       'value': '8347'},
#      {'key': 'Nucleotide sequences after length filtering', 'value': '8347'},
#      {'key': 'Nucleotide sequences after undetermined bases filtering',
#       'value': '8347'},
#      {'key': 'Predicted SSU sequences', 'value': '0'},
#      {'key': 'Predicted LSU sequences', 'value': '70'}],
#     'experiment-type': 'amplicon',
#     'accession': 'MGYA00429287',
#     'is-private': False,
#     'last-update': '2024-01-29T15:29:19.757516',
#     'mgx-accession': None,
#     'complete-time': '2020-03-11T11:29:04',
#     'instrument-platform': 'ILLUMINA',
#     'instrument-model': 'Illumina MiSeq'},
#    'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429287/go-terms'}},
#     'run': {'data': {'type': 'runs', 'id': 'ERR2237856'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR2237856'}},
#     'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429287/downloads'}},
#     'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429287/go-slim'}},
#     'assembly': {'data': None},
#     'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429287/interpro-identifiers'}},
#     'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429287/taxonomy/unite'}},
#     'study': {'data': {'type': 'studies', 'id': 'MGYS00002115'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002115'}},
#     'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429287/taxonomy/ssu'}},
#     'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429287/taxonomy/lsu'}},
#     'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429287/taxonomy/itsonedb'}},
#     'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429287/antismash-gene-clusters'}},
#     'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429287/taxonomy'}},
#     'sample': {'data': {'type': 'samples', 'id': 'ERS2075823'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS2075823'}},
#     'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429287/genome-properties'}}},
#    'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429287'}},
#   {'type': 'analysis-jobs',
#    'id': 'MGYA00429288',
#    'attributes': {'analysis-status': 'completed',
#     'pipeline-version': '5.0',
#     'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#       'value': '84803'},
#      {'key': 'Nucleotide sequences after format-specific filtering',
#       'value': '84788'},
#      {'key': 'Nucleotide sequences after length filtering', 'value': '84788'},
#      {'key': 'Nucleotide sequences after undetermined bases filtering',
#       'value': '84788'},
#      {'key': 'Predicted SSU sequences', 'value': '2'},
#      {'key': 'Predicted LSU sequences', 'value': '401'}],
#     'experiment-type': 'amplicon',
#     'accession': 'MGYA00429288',
#     'is-private': False,
#     'last-update': '2024-01-29T15:29:19.757516',
#     'mgx-accession': None,
#     'complete-time': '2020-03-11T11:21:45',
#     'instrument-platform': 'ILLUMINA',
#     'instrument-model': 'Illumina MiSeq'},
#    'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429288/go-terms'}},
#     'run': {'data': {'type': 'runs', 'id': 'ERR2237854'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR2237854'}},
#     'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429288/downloads'}},
#     'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429288/go-slim'}},
#     'assembly': {'data': None},
#     'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429288/interpro-identifiers'}},
#     'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429288/taxonomy/unite'}},
#     'study': {'data': {'type': 'studies', 'id': 'MGYS00002115'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00002115'}},
#     'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429288/taxonomy/ssu'}},
#     'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429288/taxonomy/lsu'}},
#     'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429288/taxonomy/itsonedb'}},
#     'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429288/antismash-gene-clusters'}},
#     'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429288/taxonomy'}},
#     'sample': {'data': {'type': 'samples', 'id': 'ERS2075821'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS2075821'}},
#     'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429288/genome-properties'}}},
#    'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429288'}},
#   {'type': 'analysis-jobs',
#    'id': 'MGYA00429312',
#    'attributes': {'analysis-status': 'completed',
#     'pipeline-version': '5.0',
#     'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#       'value': '35959'},
#      {'key': 'Nucleotide sequences after format-specific filtering',
#       'value': '31201'},
#      {'key': 'Nucleotide sequences after length filtering', 'value': '31201'},
#      {'key': 'Nucleotide sequences after undetermined bases filtering',
#       'value': '31201'},
#      {'key': 'Predicted SSU sequences', 'value': '31214'},
#      {'key': 'Predicted LSU sequences', 'value': '0'}],
#     'experiment-type': 'amplicon',
#     'accession': 'MGYA00429312',
#     'is-private': False,
#     'last-update': '2024-01-29T15:29:19.757516',
#     'mgx-accession': None,
#     'complete-time': '2020-03-11T09:24:37',
#     'instrument-platform': 'LS454',
#     'instrument-model': '454 GS FLX Titanium'},
#    'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429312/go-terms'}},
#     'run': {'data': {'type': 'runs', 'id': 'ERR315852'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR315852'}},
#     'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429312/downloads'}},
#     'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429312/go-slim'}},
#     'assembly': {'data': None},
#     'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429312/interpro-identifiers'}},
#     'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429312/taxonomy/unite'}},
#     'study': {'data': {'type': 'studies', 'id': 'MGYS00000492'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00000492'}},
#     'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429312/taxonomy/ssu'}},
#     'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429312/taxonomy/lsu'}},
#     'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429312/taxonomy/itsonedb'}},
#     'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429312/antismash-gene-clusters'}},
#     'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429312/taxonomy'}},
#     'sample': {'data': {'type': 'samples', 'id': 'ERS477999'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS477999'}},
#     'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429312/genome-properties'}}},
#    'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429312'}},
#   {'type': 'analysis-jobs',
#    'id': 'MGYA00429313',
#    'attributes': {'analysis-status': 'completed',
#     'pipeline-version': '5.0',
#     'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#       'value': '44989'},
#      {'key': 'Nucleotide sequences after format-specific filtering',
#       'value': '32627'},
#      {'key': 'Nucleotide sequences after length filtering', 'value': '32627'},
#      {'key': 'Nucleotide sequences after undetermined bases filtering',
#       'value': '32627'},
#      {'key': 'Predicted SSU sequences', 'value': '32426'},
#      {'key': 'Predicted LSU sequences', 'value': '0'}],
#     'experiment-type': 'amplicon',
#     'accession': 'MGYA00429313',
#     'is-private': False,
#     'last-update': '2024-01-29T15:29:19.757516',
#     'mgx-accession': None,
#     'complete-time': '2020-03-11T14:41:28',
#     'instrument-platform': 'LS454',
#     'instrument-model': '454 GS FLX Titanium'},
#    'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429313/go-terms'}},
#     'run': {'data': {'type': 'runs', 'id': 'ERR315850'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR315850'}},
#     'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429313/downloads'}},
#     'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429313/go-slim'}},
#     'assembly': {'data': None},
#     'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429313/interpro-identifiers'}},
#     'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429313/taxonomy/unite'}},
#     'study': {'data': {'type': 'studies', 'id': 'MGYS00000492'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00000492'}},
#     'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429313/taxonomy/ssu'}},
#     'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429313/taxonomy/lsu'}},
#     'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429313/taxonomy/itsonedb'}},
#     'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429313/antismash-gene-clusters'}},
#     'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429313/taxonomy'}},
#     'sample': {'data': {'type': 'samples', 'id': 'ERS478017'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS478017'}},
#     'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429313/genome-properties'}}},
#    'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429313'}},
#   {'type': 'analysis-jobs',
#    'id': 'MGYA00429314',
#    'attributes': {'analysis-status': 'completed',
#     'pipeline-version': '5.0',
#     'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#       'value': '15487'},
#      {'key': 'Nucleotide sequences after format-specific filtering',
#       'value': '11828'},
#      {'key': 'Nucleotide sequences after length filtering', 'value': '11828'},
#      {'key': 'Nucleotide sequences after undetermined bases filtering',
#       'value': '11828'},
#      {'key': 'Predicted SSU sequences', 'value': '2'},
#      {'key': 'Predicted LSU sequences', 'value': '0'}],
#     'experiment-type': 'amplicon',
#     'accession': 'MGYA00429314',
#     'is-private': False,
#     'last-update': '2024-01-29T15:29:19.757516',
#     'mgx-accession': None,
#     'complete-time': '2020-08-21T11:24:30',
#     'instrument-platform': 'LS454',
#     'instrument-model': '454 GS FLX Titanium'},
#    'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429314/go-terms'}},
#     'run': {'data': {'type': 'runs', 'id': 'ERR632202'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR632202'}},
#     'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429314/downloads'}},
#     'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429314/go-slim'}},
#     'assembly': {'data': None},
#     'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429314/interpro-identifiers'}},
#     'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429314/taxonomy/unite'}},
#     'study': {'data': {'type': 'studies', 'id': 'MGYS00001811'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00001811'}},
#     'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429314/taxonomy/ssu'}},
#     'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429314/taxonomy/lsu'}},
#     'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429314/taxonomy/itsonedb'}},
#     'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429314/antismash-gene-clusters'}},
#     'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429314/taxonomy'}},
#     'sample': {'data': {'type': 'samples', 'id': 'ERS492648'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS492648'}},
#     'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429314/genome-properties'}}},
#    'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429314'}},
#   {'type': 'analysis-jobs',
#    'id': 'MGYA00429315',
#    'attributes': {'analysis-status': 'completed',
#     'pipeline-version': '5.0',
#     'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#       'value': '136377'},
#      {'key': 'Nucleotide sequences after format-specific filtering',
#       'value': '135647'},
#      {'key': 'Nucleotide sequences after length filtering', 'value': '135647'},
#      {'key': 'Nucleotide sequences after undetermined bases filtering',
#       'value': '135647'},
#      {'key': 'Predicted SSU sequences', 'value': '11'},
#      {'key': 'Predicted LSU sequences', 'value': '1'}],
#     'experiment-type': 'amplicon',
#     'accession': 'MGYA00429315',
#     'is-private': False,
#     'last-update': '2024-01-29T15:29:19.757516',
#     'mgx-accession': None,
#     'complete-time': '2020-08-21T11:25:02',
#     'instrument-platform': 'ILLUMINA',
#     'instrument-model': 'Illumina MiSeq'},
#    'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429315/go-terms'}},
#     'run': {'data': {'type': 'runs', 'id': 'ERR632201'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/ERR632201'}},
#     'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429315/downloads'}},
#     'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429315/go-slim'}},
#     'assembly': {'data': None},
#     'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429315/interpro-identifiers'}},
#     'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429315/taxonomy/unite'}},
#     'study': {'data': {'type': 'studies', 'id': 'MGYS00001811'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00001811'}},
#     'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429315/taxonomy/ssu'}},
#     'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429315/taxonomy/lsu'}},
#     'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429315/taxonomy/itsonedb'}},
#     'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429315/antismash-gene-clusters'}},
#     'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429315/taxonomy'}},
#     'sample': {'data': {'type': 'samples', 'id': 'ERS492647'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS492647'}},
#     'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429315/genome-properties'}}},
#    'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429315'}},
#   {'type': 'analysis-jobs',
#    'id': 'MGYA00429316',
#    'attributes': {'analysis-status': 'completed',
#     'pipeline-version': '5.0',
#     'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#       'value': '65644'},
#      {'key': 'Nucleotide sequences after format-specific filtering',
#       'value': '56368'},
#      {'key': 'Nucleotide sequences after length filtering', 'value': '56368'},
#      {'key': 'Nucleotide sequences after undetermined bases filtering',
#       'value': '56368'},
#      {'key': 'Predicted SSU sequences', 'value': '12'},
#      {'key': 'Predicted LSU sequences', 'value': '0'}],
#     'experiment-type': 'amplicon',
#     'accession': 'MGYA00429316',
#     'is-private': False,
#     'last-update': '2024-01-29T15:29:19.757516',
#     'mgx-accession': None,
#     'complete-time': '2020-08-21T11:26:50',
#     'instrument-platform': 'LS454',
#     'instrument-model': '454 GS FLX Titanium'},
# ...
#     'assembly': {'data': None},
#     'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429319/interpro-identifiers'}},
#     'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429319/taxonomy/unite'}},
#     'study': {'data': {'type': 'studies', 'id': 'MGYS00001811'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00001811'}},
#     'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429319/taxonomy/ssu'}},
#     'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429319/taxonomy/lsu'}},
#     'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429319/taxonomy/itsonedb'}},
#     'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429319/antismash-gene-clusters'}},
#     'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429319/taxonomy'}},
#     'sample': {'data': {'type': 'samples', 'id': 'ERS492648'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS492648'}},
#     'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429319/genome-properties'}}},
#    'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429319'}},
#   {'type': 'analysis-jobs',
#    'id': 'MGYA00429320',
#    'attributes': {'analysis-status': 'completed',
#     'pipeline-version': '5.0',
#     'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#       'value': '132'},
#      {'key': 'Nucleotide sequences after format-specific filtering',
#       'value': '130'},
#      {'key': 'Nucleotide sequences after length filtering', 'value': '130'},
#      {'key': 'Nucleotide sequences after undetermined bases filtering',
#       'value': '130'},
#      {'key': 'Predicted SSU sequences', 'value': '0'},
#      {'key': 'Predicted LSU sequences', 'value': '74'}],
#     'experiment-type': 'amplicon',
#     'accession': 'MGYA00429320',
#     'is-private': False,
#     'last-update': '2024-01-29T15:29:19.757516',
#     'mgx-accession': None,
#     'complete-time': '2020-11-14T12:46:12',
#     'instrument-platform': 'LS454',
#     'instrument-model': '454 GS Junior'},
#    'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429320/go-terms'}},
#     'run': {'data': {'type': 'runs', 'id': 'DRR011295'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/DRR011295'}},
#     'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429320/downloads'}},
#     'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429320/go-slim'}},
#     'assembly': {'data': None},
#     'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429320/interpro-identifiers'}},
#     'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429320/taxonomy/unite'}},
#     'study': {'data': {'type': 'studies', 'id': 'MGYS00005240'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00005240'}},
#     'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429320/taxonomy/ssu'}},
#     'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429320/taxonomy/lsu'}},
#     'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429320/taxonomy/itsonedb'}},
#     'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429320/antismash-gene-clusters'}},
#     'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429320/taxonomy'}},
#     'sample': {'data': {'type': 'samples', 'id': 'DRS010096'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/DRS010096'}},
#     'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429320/genome-properties'}}},
#    'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429320'}},
#   {'type': 'analysis-jobs',
#    'id': 'MGYA00429321',
#    'attributes': {'analysis-status': 'completed',
#     'pipeline-version': '5.0',
#     'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#       'value': '113'},
#      {'key': 'Nucleotide sequences after format-specific filtering',
#       'value': '113'},
#      {'key': 'Nucleotide sequences after length filtering', 'value': '113'},
#      {'key': 'Nucleotide sequences after undetermined bases filtering',
#       'value': '113'},
#      {'key': 'Predicted SSU sequences', 'value': '0'},
#      {'key': 'Predicted LSU sequences', 'value': '46'}],
#     'experiment-type': 'amplicon',
#     'accession': 'MGYA00429321',
#     'is-private': False,
#     'last-update': '2024-01-29T15:29:19.757516',
#     'mgx-accession': None,
#     'complete-time': '2020-11-15T20:52:30',
#     'instrument-platform': 'LS454',
#     'instrument-model': '454 GS Junior'},
#    'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429321/go-terms'}},
#     'run': {'data': {'type': 'runs', 'id': 'DRR011291'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/DRR011291'}},
#     'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429321/downloads'}},
#     'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429321/go-slim'}},
#     'assembly': {'data': None},
#     'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429321/interpro-identifiers'}},
#     'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429321/taxonomy/unite'}},
#     'study': {'data': {'type': 'studies', 'id': 'MGYS00005240'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00005240'}},
#     'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429321/taxonomy/ssu'}},
#     'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429321/taxonomy/lsu'}},
#     'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429321/taxonomy/itsonedb'}},
#     'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429321/antismash-gene-clusters'}},
#     'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429321/taxonomy'}},
#     'sample': {'data': {'type': 'samples', 'id': 'DRS010092'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/DRS010092'}},
#     'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429321/genome-properties'}}},
#    'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429321'}},
#   {'type': 'analysis-jobs',
#    'id': 'MGYA00429322',
#    'attributes': {'analysis-status': 'completed',
#     'pipeline-version': '5.0',
#     'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#       'value': '1'},
#      {'key': 'Nucleotide sequences after format-specific filtering',
#       'value': '1'},
#      {'key': 'Nucleotide sequences after length filtering', 'value': '1'},
#      {'key': 'Nucleotide sequences after undetermined bases filtering',
#       'value': '1'},
#      {'key': 'Predicted SSU sequences', 'value': '0'},
#      {'key': 'Predicted LSU sequences', 'value': '1'}],
#     'experiment-type': 'amplicon',
#     'accession': 'MGYA00429322',
#     'is-private': False,
#     'last-update': '2024-01-29T15:29:19.757516',
#     'mgx-accession': None,
#     'complete-time': '2020-11-14T09:07:44',
#     'instrument-platform': 'LS454',
#     'instrument-model': '454 GS Junior'},
#    'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429322/go-terms'}},
#     'run': {'data': {'type': 'runs', 'id': 'DRR010906'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/DRR010906'}},
#     'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429322/downloads'}},
#     'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429322/go-slim'}},
#     'assembly': {'data': None},
#     'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429322/interpro-identifiers'}},
#     'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429322/taxonomy/unite'}},
#     'study': {'data': {'type': 'studies', 'id': 'MGYS00005240'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00005240'}},
#     'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429322/taxonomy/ssu'}},
#     'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429322/taxonomy/lsu'}},
#     'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429322/taxonomy/itsonedb'}},
#     'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429322/antismash-gene-clusters'}},
#     'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429322/taxonomy'}},
#     'sample': {'data': {'type': 'samples', 'id': 'DRS009707'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/DRS009707'}},
#     'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429322/genome-properties'}}},
#    'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429322'}},
#   {'type': 'analysis-jobs',
#    'id': 'MGYA00429323',
#    'attributes': {'analysis-status': 'completed',
#     'pipeline-version': '5.0',
#     'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#       'value': '67'},
#      {'key': 'Nucleotide sequences after format-specific filtering',
#       'value': '63'},
#      {'key': 'Nucleotide sequences after length filtering', 'value': '63'},
#      {'key': 'Nucleotide sequences after undetermined bases filtering',
#       'value': '63'},
#      {'key': 'Predicted SSU sequences', 'value': '0'},
#      {'key': 'Predicted LSU sequences', 'value': '8'}],
#     'experiment-type': 'amplicon',
#     'accession': 'MGYA00429323',
#     'is-private': False,
#     'last-update': '2024-01-29T15:29:19.757516',
#     'mgx-accession': None,
#     'complete-time': '2020-11-15T21:44:02',
#     'instrument-platform': 'LS454',
#     'instrument-model': '454 GS Junior'},
#    'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429323/go-terms'}},
#     'run': {'data': {'type': 'runs', 'id': 'DRR010749'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/DRR010749'}},
#     'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429323/downloads'}},
#     'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429323/go-slim'}},
#     'assembly': {'data': None},
#     'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429323/interpro-identifiers'}},
#     'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429323/taxonomy/unite'}},
#     'study': {'data': {'type': 'studies', 'id': 'MGYS00005240'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00005240'}},
#     'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429323/taxonomy/ssu'}},
#     'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429323/taxonomy/lsu'}},
#     'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429323/taxonomy/itsonedb'}},
#     'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429323/antismash-gene-clusters'}},
#     'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429323/taxonomy'}},
#     'sample': {'data': {'type': 'samples', 'id': 'DRS009550'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/DRS009550'}},
#     'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429323/genome-properties'}}},
#    'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429323'}},
#   {'type': 'analysis-jobs',
#    'id': 'MGYA00429324',
#    'attributes': {'analysis-status': 'completed',
#     'pipeline-version': '5.0',
#     'analysis-summary': [{'key': 'Submitted nucleotide sequences',
#       'value': '131'},
#      {'key': 'Nucleotide sequences after format-specific filtering',
#       'value': '128'},
#      {'key': 'Nucleotide sequences after length filtering', 'value': '128'},
#      {'key': 'Nucleotide sequences after undetermined bases filtering',
#       'value': '128'},
#      {'key': 'Predicted SSU sequences', 'value': '0'},
#      {'key': 'Predicted LSU sequences', 'value': '52'}],
#     'experiment-type': 'amplicon',
#     'accession': 'MGYA00429324',
#     'is-private': False,
#     'last-update': '2024-01-29T15:29:19.757516',
#     'mgx-accession': None,
#     'complete-time': '2020-11-14T09:54:23',
#     'instrument-platform': 'LS454',
#     'instrument-model': '454 GS Junior'},
#    'relationships': {'go-terms': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429324/go-terms'}},
#     'run': {'data': {'type': 'runs', 'id': 'DRR010664'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/runs/DRR010664'}},
#     'downloads': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429324/downloads'}},
#     'go-slim': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429324/go-slim'}},
#     'assembly': {'data': None},
#     'interpro-identifiers': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429324/interpro-identifiers'}},
#     'taxonomy-itsunite': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429324/taxonomy/unite'}},
#     'study': {'data': {'type': 'studies', 'id': 'MGYS00005240'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00005240'}},
#     'taxonomy-ssu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429324/taxonomy/ssu'}},
#     'taxonomy-lsu': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429324/taxonomy/lsu'}},
#     'taxonomy-itsonedb': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429324/taxonomy/itsonedb'}},
#     'antismash-gene-clusters': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429324/antismash-gene-clusters'}},
#     'taxonomy': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429324/taxonomy'}},
#     'sample': {'data': {'type': 'samples', 'id': 'DRS009465'},
#      'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/samples/DRS009465'}},
#     'genome-properties': {'links': {'related': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429324/genome-properties'}}},
#    'links': {'self': 'https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00429324'}}],
#  'meta': {'pagination': {'page': 1, 'pages': 9113, 'count': 227821}}}

# %%
analysisId = 'MGYS00006680'
with APISession("https://www.ebi.ac.uk/metagenomics/api/v1") as session:
    for download in session.iterate(f"studies/{analysisId}/downloads"):
        print(f"{download.alias}: {download.description.label}, {download.links.self}")
# Out:
# SRP237882_phylum_taxonomy_abundances_SSU_v5.0.tsv: Phylum level taxonomies SSU, https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00006680/pipelines/5.0/file/SRP237882_phylum_taxonomy_abundances_SSU_v5.0.tsv
# SRP237882_taxonomy_abundances_SSU_v5.0.tsv: Taxonomic assignments SSU, https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00006680/pipelines/5.0/file/SRP237882_taxonomy_abundances_SSU_v5.0.tsv
# SRP237882_phylum_taxonomy_abundances_LSU_v5.0.tsv: Phylum level taxonomies LSU, https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00006680/pipelines/5.0/file/SRP237882_phylum_taxonomy_abundances_LSU_v5.0.tsv
# SRP237882_taxonomy_abundances_LSU_v5.0.tsv: Taxonomic assignments LSU, https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00006680/pipelines/5.0/file/SRP237882_taxonomy_abundances_LSU_v5.0.tsv
# SRP237882_phylum_taxonomy_abundances_itsonedb_v5.0.tsv: Phylum level taxonomies ITSoneDB, https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00006680/pipelines/5.0/file/SRP237882_phylum_taxonomy_abundances_itsonedb_v5.0.tsv
# SRP237882_taxonomy_abundances_itsonedb_v5.0.tsv: Taxonomic assignments ITSoneDB, https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00006680/pipelines/5.0/file/SRP237882_taxonomy_abundances_itsonedb_v5.0.tsv
# SRP237882_phylum_taxonomy_abundances_unite_v5.0.tsv: Phylum level taxonomies UNITE, https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00006680/pipelines/5.0/file/SRP237882_phylum_taxonomy_abundances_unite_v5.0.tsv
# SRP237882_taxonomy_abundances_unite_v5.0.tsv: Taxonomic assignments UNITE, https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00006680/pipelines/5.0/file/SRP237882_taxonomy_abundances_unite_v5.0.tsv

# %%
# Data download
from urllib.request import urlretrieve

analysisId = 'MGYS00006680'
with APISession("https://www.ebi.ac.uk/metagenomics/api/v1") as session:
    for download in session.iterate(f"studies/{analysisId}/downloads"):
        print(f"{download.alias}: {download.description.label}")
        if download.description.label == 'Taxonomic assignments SSU':
            print(f"Downloading {download.alias}...")
            urlretrieve(download.links.self.url, 'test.tsv')
# Out:
# SRP237882_phylum_taxonomy_abundances_SSU_v5.0.tsv: Phylum level taxonomies SSU
# SRP237882_taxonomy_abundances_SSU_v5.0.tsv: Taxonomic assignments SSU
# Downloading SRP237882_taxonomy_abundances_SSU_v5.0.tsv...
# SRP237882_phylum_taxonomy_abundances_LSU_v5.0.tsv: Phylum level taxonomies LSU
# SRP237882_taxonomy_abundances_LSU_v5.0.tsv: Taxonomic assignments LSU
# SRP237882_phylum_taxonomy_abundances_itsonedb_v5.0.tsv: Phylum level taxonomies ITSoneDB
# SRP237882_taxonomy_abundances_itsonedb_v5.0.tsv: Taxonomic assignments ITSoneDB
# SRP237882_phylum_taxonomy_abundances_unite_v5.0.tsv: Phylum level taxonomies UNITE
# SRP237882_taxonomy_abundances_unite_v5.0.tsv: Taxonomic assignments UNITE

# %%
# https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00006680/pipelines/5.0/file/SRP237882_taxonomy_abundances_SSU_v5.0.tsv

with APISession("https://www.ebi.ac.uk/metagenomics/api/v1") as session:
    for download in session.iterate(f"studies/MGYS00006680/pipelines/5.0/file"):
        print(f"{download.alias}: {download.description.label}")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/miniforge3/envs/momics-demos/lib/python3.13/site-packages/requests/models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/miniforge3/envs/momics-demos/lib/python3.13/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~/miniforge3/envs/momics-demos/lib/python3.13/json/decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# --> 345 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346 end = _w(s, end).end()
#
# File ~/miniforge3/envs/momics-demos/lib/python3.13/json/decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 2 column 1 (char 1)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[23], line 4
#       1 # https://www.ebi.ac.uk/metagenomics/api/v1/studies/MGYS00006680/pipelines/5.0/file/SRP237882_taxonomy_abundances_SSU_v5.0.tsv
#       3 with APISession("https://www.ebi.ac.uk/metagenomics/api/v1") as session:
# ----> 4     for download in session.iterate(f"studies/MGYS00006680/pipelines/5.0/file"):
#       5         print(f"{download.alias}: {download.description.label}")
#
# File ~/miniforge3/envs/momics-demos/lib/python3.13/site-packages/jsonapi_client/session.py:368, in Session._iterate_sync(self, resource_type, filter)
#     366 def _iterate_sync(self, resource_type: str, filter: 'Modifier'=None) \
#     367         -> 'Iterator[ResourceObject]':
# --> 368     doc = self.get(resource_type, filter)
#     369     yield from doc._iterator_sync()
#
# File ~/miniforge3/envs/momics-demos/lib/python3.13/site-packages/jsonapi_client/session.py:364, in Session.get(self, resource_type, resource_id_or_filter)
#     362     return self._get_async(resource_type, resource_id_or_filter)
#     363 else:
# --> 364     return self._get_sync(resource_type, resource_id_or_filter)
#
# File ~/miniforge3/envs/momics-demos/lib/python3.13/site-packages/jsonapi_client/session.py:340, in Session._get_sync(self, resource_type, resource_id_or_filter)
#     337 resource_id, filter_ = self._resource_type_and_filter(
#     338                                                         resource_id_or_filter)
#     339 url = self._url_for_resource(resource_type, resource_id, filter_)
# --> 340 return self.fetch_document_by_url(url)
#
# File ~/miniforge3/envs/momics-demos/lib/python3.13/site-packages/jsonapi_client/session.py:457, in Session.fetch_document_by_url(self, url)
#     450 """
#     451 Internal use.
#     452
#     453 Fetch Document from server by url.
#     454 """
#     456 # TODO: should we try to guess type, id from url?
# --> 457 return self.documents_by_link.get(url) or self._ext_fetch_by_url(url)
#
# File ~/miniforge3/envs/momics-demos/lib/python3.13/site-packages/jsonapi_client/session.py:471, in Session._ext_fetch_by_url(self, url)
#     470 def _ext_fetch_by_url(self, url: str) -> 'Document':
# --> 471     json_data = self._fetch_json(url)
#     472     return self.read(json_data, url)
#
# File ~/miniforge3/envs/momics-demos/lib/python3.13/site-packages/jsonapi_client/session.py:489, in Session._fetch_json(self, url)
#     487 logger.info('Fetching document from url %s', parsed_url)
#     488 response = requests.get(parsed_url.geturl(), **self._request_kwargs)
# --> 489 response_content = response.json()
#     490 if response.status_code == HttpStatus.OK_200:
#     491     return response_content
#
# File ~/miniforge3/envs/momics-demos/lib/python3.13/site-packages/requests/models.py:978, in Response.json(self, **kwargs)
#     974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 2 column 1 (char 1)

# %%
analysisId = 'MGYS00006680'
with APISession("https://www.ebi.ac.uk/metagenomics/api/v1") as session:
    for download in session.iterate(f"studies/{analysisId}#analyses"):
        print(f"{download.alias}: {download.description.label}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/momics-demos/lib/python3.13/site-packages/jsonapi_client/common.py:169, in AttributeProxy.__getattr__(self, item)
#     168 try:
# --> 169     return self[jsonify_attribute_name(item)]
#     170 except KeyError:
#
# File ~/miniforge3/envs/momics-demos/lib/python3.13/site-packages/jsonapi_client/resourceobject.py:357, in ResourceObject.fields.<locals>.Proxy.__getitem__(proxy, item)
#     356 if rv is NOT_FOUND:
# --> 357     return self.relationship_resource[item]
#     358 else:
#
# File ~/miniforge3/envs/momics-demos/lib/python3.13/site-packages/jsonapi_client/resourceobject.py:400, in ResourceObject.relationship_resource.<locals>.Proxy.__getitem__(proxy, item)
#     399 def __getitem__(proxy, item):
# --> 400     rel = self.relationships[item]
#     401     if self.session.enable_async:
#     402         # With async it's more convenient to access Relationship object
#
# File ~/miniforge3/envs/momics-demos/lib/python3.13/site-packages/jsonapi_client/common.py:162, in AttributeProxy.__getitem__(self, item)
#     161 def __getitem__(self, item):
# --> 162     return self._target_object[item]
#
# KeyError: 'alias'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 4
#       2 with APISession("https://www.ebi.ac.uk/metagenomics/api/v1") as session:
#       3     for download in session.iterate(f"studies/{analysisId}#analyses"):
# ----> 4         print(f"{download.alias}: {download.description.label}")
#
# File ~/miniforge3/envs/momics-demos/lib/python3.13/site-packages/jsonapi_client/resourceobject.py:461, in ResourceObject.__getattr__(self, attr_name)
#     460 def __getattr__(self, attr_name):
# --> 461     return getattr(self.fields, attr_name)
#
# File ~/miniforge3/envs/momics-demos/lib/python3.13/site-packages/jsonapi_client/common.py:171, in AttributeProxy.__getattr__(self, item)
#     169     return self[jsonify_attribute_name(item)]
#     170 except KeyError:
# --> 171     raise AttributeError
#
# AttributeError:

# %% [markdown]
# ## Get information for a specific genus or species
#
# Examples: Search for available ressources for a specific genus or species of interest.
#
# - Listeria
# - Listeria monocytogenes
#
# The taxon-lineage field contains domain, phylum, class, order, family, genus, species, subspecies as
#
# `d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactobacillales;f__Listeriaceae;g__Listeria;s__Listeria` monocytogenes(example for Listeria monocytogenes).
#
# The filter can use the full lineage
# `d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactobacillales;f__Listeriaceae;g__Listeria` or only part of it `g__Listeria` or `Listeria`.

# %%
genus_filter = 'Listeria'
species_filter = 'Listeria monocytogenes'

with APISession("https://www.ebi.ac.uk/metagenomics/api/v1") as mgnify:
    search_filter = Modifier(f"taxon_lineage={genus_filter}")
    resources = map(lambda r: r.json, mgnify.iterate(endpoint_name, filter=search_filter))
    resources_df = pd.json_normalize(resources)

# %%
# Display the table containing the results of the query
resources_df

# %% [markdown]
# Query the database with the 'Listeria monocytogenes' filter and store the results in a Pandas DataFrame.

# %%
with APISession("https://www.ebi.ac.uk/metagenomics/api/v1") as mgnify:
    search_filter_2 = Modifier(f"taxon_lineage={species_filter}")
    resources_2 = map(lambda r: r.json, mgnify.iterate(endpoint_name, filter=search_filter_2))
    resources_df_2 = pd.json_normalize(resources_2)

# %%
resources_df_2

# %%
resources_df.to_parquet('Listeria_resources.parquet')
listeria_df = pd.read_parquet('Listeria_resources.parquet')
listeria_df

# %% [markdown]
# Query and save the dataset as parquet file
#
# To query the whole dataset, we can use the same method as previously. The only difference is that no filter is passed to the query.
#
# Warning: Querying without filter is computationally expensive and will take time.
#
# A pre-fetched copy of the data (as of 8 November 2022) is available in ../example-data/genomes/all_genome_resources.parquet.

# %%
# Careful, this takes a while to run
# on the order level, the query takes 
domain_filter = 'Bacteria'
order_filter = 'Lactobacillales'

with APISession("https://www.ebi.ac.uk/metagenomics/api/v1") as mgnify:
    search_filter_3 = Modifier(f"taxon_lineage={order_filter}")
    resources_all = map(lambda r: r.json, mgnify.iterate(endpoint_name, filter=search_filter_3))
    resources_all_df = pd.json_normalize(resources_all)

resources_all_df
resources_all_df.to_parquet('latest_genome_resources.parquet')

# %% [markdown]
# ## Spark session to load all that data

# %%
from pyspark.sql import SparkSession

import pyspark.sql.functions as F
import pyspark

# %%
pyspark.conf.SparkConf().set("spark.sql.debug.maxToStringFields", 500)

# %%
spark = SparkSession.builder.getOrCreate()

# %%
all_genomes_df = spark.read.parquet('latest_genome_resources.parquet')

# %%
all_genomes_df.count(), len(all_genomes_df.columns)

# %%
all_genomes_df.describe().show(truncate=False, vertical=True)

# %% [markdown]
# ### Get most represented genus

# %%
# To see a sample of taxon-lineages present in the dataset:
all_genomes_df.select(f'`attributes.taxon-lineage`').show(truncate=False)

# %%
# The total number of genomes in the dataset:
all_genomes_df.select('`id`').distinct().count()

# %%
# The number of distinct lineages:
all_genomes_df.select('`attributes.taxon-lineage`').distinct().count()

# %% [markdown]
#  ### Split taxon-lineage column into 7 columns

# %%
features = ['domain', 'phylum', 'class', 'order', 'family', 'genus', 'species']

all_genomes_tax_df = reduce(lambda df, i: df.withColumn(features[i], F.col('lineage_split')[i]),
    range(len(features)),
    all_genomes_df.withColumn('lineage_split', F.split(F.col('`attributes.taxon-lineage`'), ';')),
)

all_genomes_tax_df.select(features).show(n=5)

# %% [markdown]
# ### Query examples

# %%
# To search the most represented taxon:
all_genomes_tax_df.groupby('`attributes.taxon-lineage`').count().filter(F.col('count')>100).show(truncate=False)

# %%
# To search for a particular lineage and count how many times it appears:
all_genomes_tax_df.filter(F.col('`attributes.taxon-lineage`').startswith('d__Bacteria;p__Actinobacteriota;c__Coriobacteriia;o__Coriobacteriales;f__Coriobacteriaceae;g__Collinsella')).count()

# %%
# To search for a particular genus and count how many times it appears:
all_genomes_tax_df.filter(F.col('`attributes.taxon-lineage`').contains('Collinsella')).count()

# %%
# To search for the most or least represented genus, species, ... in this dataset for example. The search is more flexible than for the full taxon.
all_genomes_tax_df.groupby('genus').count().filter(F.col('count')>100).show()

# %%
all_genomes_tax_df.filter(F.col('genus').isin('g__Prevotella', 'g__RC9', 'g__Collinsella')).groupby('genus').agg(F.countDistinct('species')).show()

# %%
# To see some of the Collinsella species in the dataset:
all_genomes_tax_df.filter(F.col('genus')=='g__Collinsella').select('species').distinct().show(truncate=False)

# %% [markdown]
# ## Graphics

# %%
all_genomes_tax_df.count()

# %%
all_genomes_tax_df.select([F.count_distinct(x).alias(f'{features[i]}_count') for i, x in enumerate([*features])]).show()

# %%
import holoviews as hv
hv.extension('bokeh')

def get_sankey(df, cat_cols=[], value_cols='', title='Sankey Diagram'):
    # Colors
    colorPalette = ['rgba(31, 119, 180, 0.8)',
     'rgba(255, 127, 14, 0.8)',
     'rgba(44, 160, 44, 0.8)',
     'rgba(214, 39, 40, 0.8)',
     'rgba(148, 103, 189, 0.8)',
     'rgba(140, 86, 75, 0.8)',
     'rgba(227, 119, 194, 0.8)',
     'rgba(127, 127, 127, 0.8)']
    labelList = []
    colorNumList = []
    for catCol in cat_cols:
        labelListTemp =  list(set(df[catCol].values))
        colorNumList.append(len(labelListTemp))
        labelList = labelList + labelListTemp
 
    # remove duplicates from labelList
    labelList = list(dict.fromkeys(labelList))
 
    # define colors based on number of levels
    colorList = []
    for idx, colorNum in enumerate(colorNumList):
        colorList = colorList + [colorPalette[idx]]*colorNum

    # transform df into a source-target pair
    for i in range(len(cat_cols)-1):
        if i==0:
            sourceTargetDf = df[[cat_cols[i],cat_cols[i+1],value_cols]]
            sourceTargetDf.columns = ['source','target','count']
        else:
            tempDf = df[[cat_cols[i],cat_cols[i+1],value_cols]]
            tempDf.columns = ['source','target','count']
            sourceTargetDf = pd.concat([sourceTargetDf,tempDf])
        sourceTargetDf = sourceTargetDf.groupby(['source','target']).agg({'count':'sum'}).reset_index()
 
    # add index for source-target pair
    sourceTargetDf['sourceID'] = sourceTargetDf['source'].apply(lambda x: labelList.index(x))
    sourceTargetDf['targetID'] = sourceTargetDf['target'].apply(lambda x: labelList.index(x))
 
    # creating data for the sankey diagram
    data = dict(
        type='sankey',
        node = dict(
            pad = 15,
            thickness = 20,
            line = dict(
                color = "black",
                width = 0.5
            ),
            label = labelList,
            color = colorList
        ),
        link = dict(
            source = sourceTargetDf['sourceID'],
            target = sourceTargetDf['targetID'],
            value = sourceTargetDf['count']
        )
    )
    
    # override gray link colors with 'source' colors
    opacity = 0.4
    # change 'magenta' to its 'rgba' value to add opacity
    data['node']['color'] = ['rgba(255,0,255, 0.8)' if color == "magenta" else color for color in data['node']['color']]
    data['link']['color'] = [data['node']['color'][src].replace("0.8", str(opacity))
                                        for src in data['link']['source']]
    
    
    fig = go.Figure(data=[go.Sankey(
    # Define nodes
    node = dict(
      pad = 15,
      thickness = 15,
      line = dict(color = "black", width = 0.5),
      label =  data['node']['label'],
      color =  data['node']['color']
    ),
    # Add links
    link = dict(
      source =  data['link']['source'],
      target =  data['link']['target'],
      value =  data['link']['value'],
      color =  data['link']['color']
    ))])
    
    fig.update_layout(title_text=title, font_size=10)
    
    return fig.show(renderer='iframe')


# To create a Sankey diagram for the taxon lineage:
def sankey_hv():
    sankey_df = all_genomes_tax_df.groupby(features).count().toPandas()
    sankey_df = sankey_df.rename(columns={'count': 'value'})
    edges = pd.read_csv('data/health-breakup2.csv')
    sankey = hv.Sankey(edges, label='A Breakout of National Health Care Expenditures')
    sankey.opts(label_position='left', edge_color='target', node_color='index', cmap='tab20')

# %%
sankey_df = all_genomes_tax_df.groupby(features).count().toPandas()
sankey_df = sankey_df.rename(columns={'count': 'value'})
sankey_df.head()

# %%
sankey = hv.Sankey(sankey_df[['phylum', "species", "value"]], label='Taxon Lineage')
sankey.opts(width=600, height=400)

# %%
# Convert Spark DataFrame to Pandas DataFrame:
pdf = all_genomes_tax_df.select(features).groupby(features).count().toPandas()

# %% [markdown]
# ### Representation of a sample of the genomes present in the dataset: example from the order of the Lactobacillales.

# %%
pdf_lactobacillales = all_genomes_tax_df.filter(F.col('order')=='o__Lactobacillales').select(features).groupby(features).count().toPandas()
# fig_l = get_sankey(pdf_lactobacillales,cat_cols=features[0:6], value_cols='count',title='Genomes from the Lactobacillales order')

# Note that there are too many distinct species in the Lactobacillales order to show individually:
all_genomes_tax_df.filter(F.col('order')=='o__Lactobacillales').select('species').distinct().count()

# %% [markdown]
# ### Information such as genome length or GC-content can also be represented
#
# We can group and visualise these at different levels like family, genus, species... depending on the number of sequences available and on the biological significance.

# %%
lactobacillales_df = all_genomes_tax_df.filter(F.col('order')=='o__Lactobacillales').orderBy('family').toPandas()
lactobacillales_count = all_genomes_tax_df.filter(F.col('order')=='o__Lactobacillales').groupby('family').count().orderBy('family').toPandas()
lactobacillales_count

# %%
fig = plt.figure(figsize=(10, 10), layout="constrained")
spec = fig.add_gridspec(3, 1)

ax00 = fig.add_subplot(spec[0, 0])
sns.barplot(data=lactobacillales_count, x='family', y='count')
plt.ylabel("Number of genome available")

ax10 = fig.add_subplot(spec[1, 0])
sns.boxplot(data=lactobacillales_df, x='family', y='attributes.length')
plt.ylabel("Genome length (bp)")
#plt.xlabel("Family of the Lactobacillales order")

ax20 = fig.add_subplot(spec[2, 0])
sns.boxplot(data=lactobacillales_df, x='family', y='attributes.gc-content')
plt.ylabel("GC-content (%)")
plt.xlabel("Family of the Lactobacillales order")


fig.suptitle('Number of genomes avalaible, genome length and GC-content of bacteria belonging the Lactobacillales order')

# %%
fig = plt.figure(figsize=(20, 5))
spec = fig.add_gridspec(1, 2)

#ax00 = fig.add_subplot(spec[0, 0])
#lactobacillales_df['relationships.biome.data.id'].hist()
#plt.xlabel("Biome")

ax01 = fig.add_subplot(spec[0:])
lactobacillales_df['relationships.catalogue.data.id'].hist()
plt.xlabel("Catalogue")
ax01.grid(False)

fig.suptitle('Biome and Catalogue related to bacteria belonging the Lactobacillales order')

# %% [markdown]
# ### Another example: produce a quality control figure similar to Extended Data Fig. 4a of [Almeida et al 2020](https://www.nature.com/articles/s41587-020-0603-3/figures/10)

# %%
qc_df = all_genomes_tax_df.toPandas()
qc_df[['attributes.completeness', 'attributes.contamination']].describe()

# %%
fig = plt.figure(figsize=(5, 10), layout="constrained")
spec = fig.add_gridspec(1, 1)

ax00 = fig.add_subplot(spec[0, 0])
sns.boxplot(data=qc_df[['attributes.completeness', 'attributes.contamination']])
plt.ylabel("%")


fig.suptitle('Quality of genomes avalaible')

# %% [markdown]
# ## Find out whether your own MAGs are novel compared to the MGnify catalogues
#
# Another use for the MGnify genomes resource is to query your own MAG against MGnify's MAG catalogues, to see whether they are novel or already represented.
# List directories of the files to be analysed:
#
# Replace the str with your own path to folder containing your files. * allows to query all the file with the .fa extension.

# %%
files = glob.glob('../data/input_gecco/*.fa')
files

# %% [markdown]
# ### Compute a sourmash sketch for each MAG
#
# Create "sketches" for each MAG using Sourmash
#
# A sketch goes into a signature, that we will use for searching. The signature is a sort of collection of hashes that are well suited for calculating the containment of your MAGs within the catalogue's MAGs.

# %%
for mag in files:
    # The sourmash parameters are chosen to match those used within MGnify
    sketch = sourmash.MinHash(n=0, ksize=31, scaled=1000)
    
    # A fasta file may have multiple records in it. Add them all to the sourmash signature.
    for index, record in enumerate(SeqIO.parse(mag, 'fasta')):
        sketch.add_sequence(str(record.seq))
        
    # Save the sourmash sketch as a "signature" file
    signature = sourmash.SourmashSignature(sketch, name=record.name)
    with open(pp(pp(mag).name).stem + '.sig', 'wt') as fp:
        sourmash.save_signatures([signature], fp)

# %% [markdown]
# ## Fetch all of the catalogue IDs currently available on MGnify
#
# To fetch the catalogue IDs to the MGnify API, use the following endpoint: https://www.ebi.ac.uk/metagenomics/api/v1/genome-catalogues.

# %%
catalogue_endpoint = "genome-catalogues"

# %%
with APISession("https://www.ebi.ac.uk/metagenomics/api/v1") as mgnify:
    catalogues = map(lambda r: r.json, mgnify.iterate(catalogue_endpoint))
    catalogues = pd.json_normalize(catalogues)

# %%
catalogue_ids = list(catalogues['id'])
catalogue_ids

# %% [markdown]
# ## Submit a search job to the MGnify API
#
# Tosubmit a job to the MGnify API, use the following endpoint: https://www.ebi.ac.uk/metagenomics/api/v1/genomes-search/gather.
# Data will be send to the API, which is called "POST"ing data in the API world.
# This part of the API is quite specialized and so is not a formal JSON:API, the requests Python packageìs therefore used to communicate with it.

# %%
endpoint = 'https://www.ebi.ac.uk/metagenomics/api/v1/genomes-search/gather'

# %%
# Create a list of file uploads, and attach them to the API request
signatures = [open(sig, 'rb') for sig in glob.glob('*.sig')]
sketch_uploads = [('file_uploaded', signature) for signature in signatures]

# Send the API request - it specifies which catalogue to search against and attaches all of the signature files.
submitted_job = requests.post(endpoint, data={'mag_catalogues': catalogue_ids}, files=sketch_uploads).json()


map(lambda fp: fp.close(), signatures)  # tidy up open file pointers

print(submitted_job)

# %%
job_done = False
while not job_done:
    print('Checking status...')
    # The status_URL is another API endpoint that's unique for the submitted search job
    query_result = None
    
    while not query_result:
        query_result = requests.get(submitted_job['data']['status_URL'])
        print('Still waiting for jobs to complete. Current status of jobs')
        print('Will check again in 2 seconds')
        time.sleep(2) 
        
    queries_status = {sig['job_id']: sig['status'] for sig in query_result.json()['data']['signatures']}
    job_done = all(map(lambda q: q == 'SUCCESS', queries_status.values()))
    
print('Job done!')

# %%
query_result_df = pd.json_normalize(query_result.json()['data']['signatures'])
query_result_df

# %%
matches = query_result_df.dropna(subset=['result.match'])
matches
